# %% [markdown]
# # 文本分析
#
#
# 何璇 15300681068

# %% [markdown]
# ## 问题阐述
# 微信是人们社交网络的重要组成部分，微信公众号也渐渐成为当代各类型媒体的传播平台：其中既有个人、小团队经营的自媒体，又有各类企业、乃至各级政府的官方媒体。微信公众号中的文章内容与主题丰富而多变，将文章进行分门别类，一方面便于日后的深入分析，另一方面也体现出该公众号发表文章的性质与特征。但是，通常作者撰写文章时不会自主将其归为某一特定主题，所以当我们获取微信文章进行分析时，面临的是大量无标签的样本。对这类样本有两种解决方法：一是对所有训练样本进行人工分类，但这样将耗费大量人力，且难免产生一定的错误与遗漏；二是采用非监督学习的方法，让算法对这些文章自动分类，从而免去了人工分类的过程。

# %% [markdown]
# 我选用自己一直在关注的果壳公众号文章作为样本。为了测试算法的可靠性，首先我将算法用于选取的四十余篇文章，通过对小样本分类结果的分析，我们可以选择进一步优化算法，或者将其运用于人工难以标记的大型样本。

# %% [markdown]
# ## 流程

# %% [markdown]
# <img src="流程图1.png" width="60%">

# %% [markdown]
# 以上流程主要分为三块：数据导入、数据预处理与数据分析。
#
#
# 1. 数据导入
#
#    对于小样本，我们已经拥有每篇文章的txt文档，存放于selected_articles的子目录中，文档名称即为文章标题。可直接采用遍历将文档导入。对于所有样本，我们已知每篇文章的url地址，所有的地址连同标题等其他信息均存放在csv格式的文件中，我们将所有的html文档中的正文内容提取并以txt文档形式分篇保存，如此便可同之前的方法导入数据。
#
#
# 2. 数据预处理
#
#    由于数据为文本格式，我们需要对其进行分词、去停用词操作。然后选取能够描述所有文章的特征。这里我们采用向量空间模型对文章进行描述。由于文章数量越大，词汇量随之增大，这将导致特征空间的维度过大，数据的分布过于稀疏，进而影响后续聚类算法的效果。我们只选取一定数量量的词汇（关键词）作为特征。最后，我们对权重矩阵进一步预处理，如：标准化。
#
#
# 3. 数据分析
#
#    我们采用无监督学习中的聚类算法将文章分为特定数量的类，并对分类结果进行分析和讨论。

# %% [markdown]
# ## 实现技术

# %% [markdown]
# 1. 编程环境：Python 3.6(Anaconda)
# 2. 外部库：jieba, bs4, numpy, pandas, sklearn.

# %%
#调用所需模块
import jieba
from jieba import posseg
from itertools import groupby
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import os
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# 导入停用词表，并添加与公众号本身相关的词
stopwords_list = [line.strip() for line in open('stopwords.txt', 'r', encoding='utf-8').readlines()]
stopwords_list.append('果壳')
stopwords_list.append('果壳网')
stopwords_list.append('图')
stopwords_list.append('图片')
stopwords_list.append('科普')

# %% [markdown]
# ### 数据导入

# %% [markdown]
# 首先我们导入小样本中的文本，将文章标题、正文内容按顺序存放于numpy数组中。在导入的同时，我们同时对正文内容进行分词与去停用词，并存放于新的数组中，这是为了方便后续取用，避免对文本重复进行分词操作。方便起见，对于分词后的结果，我们只选择中文词汇，而忽略其他，如：英文词汇、标点。

# %%
# 定义文档存放路径
article_path = r'F:\\selected articles\\'

# %%
# 由于还没有进行函数的定义，我们先不运行这一模块，而在函数定义之后运行
# 存放文章标题
article_names = []
# 存放原始文本内容
article_texts = []
# 存放分词后的文本内容
seg_articles = []
# 存放分词、去停用词后的文本内容
seg_articles_delstp = []

# 一一读取目录中的文档
for fname in os.listdir(article_path):
    article = open(os.path.join(article_path, fname),'r',encoding='utf-8').read()
    
    article_name = fname.replace('.txt', '')
    article_names.append(article_name)
    
    article_text = article.replace('\n', '')
    article_texts.append(article_text)
    # 分词
    article_seg_list = jieba.lcut(article_text)
    
    seg_text = ''
    seg_text_delstp = ''
    
    for word in article_seg_list:
        if is_chinese(word):
            seg_text += word + ' '
            if word not in stopwords_list:
                seg_text_delstp += word + ' '
                
    seg_articles.append(seg_text)
    seg_articles_delstp.append(seg_text_delstp)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.951 seconds.
# Prefix dict has been built succesfully.

# %% [markdown]
# ### 定义函数

# %% [markdown]
# 下面我们将定义数据处理、分析过程中的函数。

# %%
# 筛选中文字符
def is_chinese(uchar):

        if uchar >= u'\u4e00' and uchar<=u'\u9fa5':
                return True

        else:
                return False

# %% [markdown]
# 之前的数据导入过程中，我们已经顺带将文本分词、停用词步骤完成。因为正文长度较长（通常几千字），我们针对正文内容进行了预先的处理，存储了预处理后的文本。对于标题，由于通常只有十几个字，所以选择在需要的时候再进行现成的处理操作，这样既不浪费空间，对算法运行时间也不会造成明显的影响。
#
# 定义对标题分词、去停用词的函数。

# %%
# 从文本中获取分词、去停用词后的中文词汇，以列表格式返回
def get_words_list_del_stpwds(text):
    # 分词
    seg_list = jieba.lcut(text)
    
    seg_list_chin = []
    for i in range(len(seg_list)):
        word = seg_list[i]
        # 选取不在停用词表的中文词汇
        if is_chinese(word) and word not in stopwords_list:
                seg_list_chin.append(word)
    
    return seg_list_chin

# %% [markdown]
# 由于我们采用向量空间模型，特征由词汇在文章中的权重表示。首先，计算词汇在文章中出现的词频。

# %%
# 获取词汇列表中每个词的频次，以词典形式返回
def get_words_dict(words_list):
    # 排序
    words_list.sort()
    # 计算每个词汇的频次
    words_dict = {}
    for key, group in groupby(words_list):
        words_dict[key] = len(list(group))
        
    return words_dict

# %% [markdown]
# 如果将所有文章中出现的词汇全部做为特征，则特征数量将远远大于文档数量，样本在高维空间分布极其稀疏，将造成“维度灾难”，不利于后续的分析。所以对特征空间进行降维尤其重要，要尽可能选取数量少但是能很好区分文章主题的关键词作为特征。特征选择有有监督与无监督两类，但是对于无标签样本集，无法使用有监督的方法，只能退而求其次，采用无监督的选择方式，这种方式的缺点主要在于：我们不知道选取的特征能否很好地区别文本，没有被选择的特征中也可能包含重要的信息。
#
# 对于小样本，因为文章数量少，词汇也较少，我们仍然有可能不进行任何降维操作，直接对不同文档聚类，然后与降维后的结果比较，有助于分析对比降维操作对数据带来的影响。

# %% [markdown]
# 接下来，我们讨论如何选取关键词。
#
# 首先，我们并非将每个文档的所有词汇收入特征集，而是假设：对于一篇文章，最能表现其主题含义的是出现频率较高的一些词（此时已经对文章做了去停用词操作），所以只要选取前n大的词汇作为关键词即可。
#
# 这种假设具有一定的依据：与主题相关的词汇总在文章中反复出现，所以高频词能够反映文章的内容。但是并非完美，因为即便使用停用词表过滤了无用、常用词，依然可能存在一些与主题无关的高频词汇。而且对于无监督方式，我们还面临一个问题，应该选取前多少个词汇作为关键词？缺乏有效的反馈，对n的选取只能来源于对维度的要求，如果要求维度尽量小，则n也应变小，此时就需要承担信息损失的风险。
#
# 为了观察降维操作是否带来明显的信息损失，进而影响聚类的结果，我们充分利用小样本，用原始数据聚类的结果与降维后的结果进行对照。

# %% [markdown]
# 接下来定义函数实现对前n个高频词的提取。

# %%
# 对一篇文章，输入词频词典，获得最高频的n个词汇
def get_most_frequent_words(words_dict, n):
    
    frequent_words = sorted(words_dict, key=words_dict.get, reverse=True)[:n]
            
    return frequent_words

# %%
# 将所有文章正文出现频次最高的n个词作为关键词，返回集合形式
def get_key_words_from_content(seg_articles_delstp, n):
    # 定义集合存放关键词
    n_articles = len(seg_articles_delstp)
    content_key_words = set()
    for i in range(n_articles):
        # 将文本转换为列表，一个元素为一个词汇
        seg_list = seg_articles_delstp[i].split()
            
        words_dict = get_words_dict(seg_list)
        frequent_words = get_most_frequent_words(words_dict, n)
        
        content_key_words.update(frequent_words)
        
    return content_key_words

# %%
# 由于前面只获取了正文中的关键词，需要继续考虑标题中的词汇
def get_keywords_from_title(article_names):
    n_articles = len(article_names)
    # 定义集合存放标题关键词
    title_key_words = set()
    for i in range(n_articles):
        title = article_names[i]
        # 提取标题中不属于停用词的中文词汇
        # 对于标题，我们不考虑频率，而是将出现的非停用词一律作为关键词
        seg_title = get_words_list_del_stpwds(title)
        title_key_words.update(seg_title)
        
    return title_key_words

# %%
# 将正文中和标题中获得的关键词合并，返回列表格式
def get_keywords(seg_articles_delstp, article_names, n):
    content_key_words = get_key_words_from_content(seg_articles_delstp, n)
    title_key_words = get_keywords_from_title(article_names)
    key_words = content_key_words
    key_words.update(title_key_words)
    return list(key_words)

# %% [markdown]
# 选取了一定量的关键词后，我们开始计算TF-IDF值。
#
# 需要申明的是，此时的降维包括特征选取还没有结束，对于DF值有一定的范围要求：关键词的文档频率不应太小——没有代表性，也不应太大——没有区分度。
#
# Sklearn库中，带有TF-IDF函数，但这里我们不采用这个函数，而是自行定义，这是为了对算法进行控制和改进。
#
# 比如，原始的TF-IDF计算不考虑标题和文本的差别，事实上，对于微信文章，标题的内容尤其重要，为了吸引兴趣、使读者对这篇文章拥有大致概念，标题通常明示或暗示文章的主要内容、主题思想，虽然我们的算法不解决语义层面的问题，与主题相关的关键词往往会出现在标题中。标题通常只有十几字，这就要求我们重视标题中出现的每个词汇，对其赋权。标题的权重应当大于正文，但这也造成一些与主题无关，或者单纯承担吸引读者功能的词汇被赋予较高的权重。所以我们应当谨慎选择权重，避免过大和过小。
#
# 另外我们之前对DF值的要求也可直接用自定义的算法实现。即去除DF值不符合要求的相应词汇。

# %%
# 计算用文档长度进行归一化的词频
def cal_word_freq(seg_articles, article_names, key_words, title_weight):
    
    n_articles = len(seg_articles)
    # 创建初始值均为零的矩阵存放词汇频率，其中行代表文章，列代表词汇
    frequency = np.zeros([n_articles, len(key_words)])
    # 创建数组存放文章的所有中文词汇数量
    article_length = np.zeros(n_articles)
    
    for i in range(n_articles):
        seg_list = seg_articles[i].split()
        # 计算文章所有中文词汇数量
        article_length[i] = len(seg_list)
        # 计算每个词汇的频次
        words_dict = get_words_dict(seg_list)
        # 对每个关键词，计算该文章中出现的归一化频率
        for j in range(len(key_words)):
            key_word = key_words[j]
            if key_word in words_dict:
                frequency[i, j] = words_dict[key_word] / article_length[i]
                
    # 加入标题的加权权重
    for i in range(n_articles):
        title = article_names[i]
        seg_title = get_words_list_del_stpwds(title)
        for word in seg_title:
            j = key_words.index(word)
            frequency[i, j] += title_weight
                
    return frequency, article_length

# %%
# 计算逆文档频率，同时返回文档频率不符合要求的词汇
def cal_idf(tf_matrix, min_df, max_df):
    # 计算每个关键词出现的文章数量
    df = np.count_nonzero(tf_matrix, axis=0)
    # 找出DF值不满足范围要求的关键词
    bad_words = np.where((df < min_df) | (df > max_df))
    # 计算逆文档频率
    d = tf_matrix.shape[0]
    idf = np.log(d / df)
    # 如果逆文档频率为零，则赋一个很小的值
    for i in range(len(idf)):
        if idf[i] == 0:
            idf[i] = 0.001
    return idf, bad_words

# %%
# 计算TF-IDF值，去掉DF值不满足要求的词
def cal_tf_idf(seg_articles, article_names, key_words, title_weight, min_df, max_df):
    
    tf_matrix, article_length = cal_word_freq(seg_articles, article_names, key_words, title_weight)
    idf, bad_words = cal_idf(tf_matrix, min_df, max_df)
    
    tf_matrix = np.delete(tf_matrix, bad_words, axis=1)
    key_words_upd = np.delete(key_words, bad_words)
    idf = np.delete(idf, bad_words)
    
    idf = idf.reshape(1, -1)
    return tf_matrix * idf, key_words_upd

# %% [markdown]
# ### 数据预处理

# %% [markdown]
# 定义函数、导入数据后，我们开始预处理流程。
#
# 下面展示数据内容。

# %%
n_articles = len(article_names)
print('n_articles: ', n_articles, '\n')
print('article_names: \n')
for name in article_names:
    print(name, '\n')
print('article_texts: ', article_texts[0][:200], '......', '\n')
print('seg_articles: ', seg_articles[0][:200], '......', '\n')
print('seg_articles_delstp: ', seg_articles_delstp[0][:200], '......', '\n')
# Out:
# n_articles:  48
#
# article_names:
#
# 7位科学家评基因编辑婴儿：不是对新知的探索，也没有医疗意义
#
# “M型病毒”这个名字哪儿来的？病毒命名有什么规律？
#
# “基因编辑婴儿”出现后，设计一个“完美婴儿”离我们还有多远？ 热点
#
# “艾滋病免疫婴儿”诞生：基因编辑技术，为何成为争议的漩涡？丨热点
#
# 一个灵敏的屁股有什么用
#
# 世界艾滋病日：阻断HIV感染的黄金24小时
#
# 为什么中国专家不研究穿山甲？因为，早被吃没了
#
# 为啥科幻小说里的打打打都要拼动力？
#
# 什么叫“外油内干”肤质啊？我到底该补水，还是该控油？
#
# 今晚吃汤圆or吃元宵？这根本不是正月十五的重点好吗！
#
# 令人们谈之色变的艾滋病，是从哪来的？
#
# 你不懂换挡：在你销魂动作的背后，变速箱都忙活些啥？
#
# 你以为侠盗猎车手是那么好当的吗？保命要紧！
#
# 你刺痛过的脸，干燥过的皮，归根结底都是这个功能有问题
#
# 你说啥？寨卡疫情是转基因蚊子引起的？有没搞错啊！
#
# 别拿蚊子不当回事儿，它们的危害可不止让你痒得难受！
#
# 别整那些没用的！我只想要一支不作妖的防晒霜
#
# 别看有些护肤品成分简单，确是敏感肌的大救星！ 好物推荐
#
# 动力科技如何用1+1推动未来快进？
#
# 古代中国有没有入侵物种造成生态灾难的事情？
#
# 围绕“基因编辑婴儿”的荒诞剧，三百年前就已经上演了
#
# 在沦落成“情人节”之前，古人的七夕比你们内涵多了
#
# 夏天被蚊子吸血很烦，那...蚊子也会感染病毒吗？
#
# 嫦娥是谁？广寒在哪？中秋怎么来？你啥也不懂，就知道吃月饼！
#
# 广东查获1.6吨穿山甲鳞片：徒有一身坚甲，难抵人类贪婪
#
# 思铂睿混动油耗有多省？我们把车子开上五环实际挑战
#
# 愚人节：不能忘记的中国传统节日！
#
# 我要吹爆能卸妆的洗面奶，你们应该没有意见吧？
#
# 接受基因疗法后，这个失去皮肤的“蝴蝶男孩”活了下来
#
# 提起“穿山甲”就想到“惨”？这9个萌点你必须得知道一下！
#
# 最后的盔犀鸟：这个活生生的物种，正一个个变成“工艺品”
#
# 比起花样百出的月饼，我独爱月亮里温柔深沉的兔子
#
# 治痘痘只会玩儿命上猛药？不同等级的痘痘要用不同治疗方法你知道吗
#
# 泰国登革热疫情爆发，国内这些地方也有感染风险！预防方法都在这
#
# 珍稀棱皮龟惨遭屠宰，海龟保育之路任重道远
#
# 甭管小年是二十三还是二十四，你们送上天的灶王都是个渣男
#
# 病毒竟然也有免疫系统！为什么？因为怕被其他病毒感染
#
# 白色情人节？别慌，回赠ta一片“海枯石烂”
#
# 穿山甲：中国人的无知贪婪，让它们离灭绝一步之遥
#
# 腊八：节日中的落难贵族？那是两大节日的合♂体！
#
# 薯片、蛋卷和爆米花：人为什么喜欢酥脆的食物？
#
# 薯片炸鸡爆米花，你为啥喜欢嘎嘣脆的食物？
#
# 蚊子：我活不了，你也别想好过
#
# 贺建奎自称“借鉴了”权威伦理指南，但他一条也没遵守
#
# 重阳节是“灾日”吗？登高吃菊花就能长寿？茱萸又是谁？
#
# 面对蝗灾，唐太宗选择了生！吞！蚂！蚱！
#
# 鸡年将至，让我们来扒一扒鸡鸡的黑历史
#
# 鹡鹚鹬鵙鹩鹛鹮鸺鹠鹪鹩䴙䴘——这都是些什么鸟字？
#
# article_texts:  编者按今天，是首例“基因编辑婴儿”事件曝光的第4天。这4天内，果壳（ID:Guokr42）整理了多个可信渠道的报道、点评，参加了贺建奎在“第二届国际人类基因组编辑峰会”上的公开演讲，并争取到了一些与会专家的独家点评。今天为大家带来的推送有三个部分：1，人类基因组编辑国际峰会上，生物科技、生命伦理领域科学家就“基因编辑婴儿”的观点；2，第二届人类基因组编辑国际峰会组委会发表的声明；3，组委会接受媒体 ......
#
# seg_articles:  编者按 今天 是 首例 基因 编辑 婴儿 事件 曝光 的 第 天 这 天内 果壳 整理 了 多个 可信 渠道 的 报道 点评 参加 了 贺建奎 在 第二届 国际 人类 基因组 编辑 峰会 上 的 公开 演讲 并 争取 到 了 一些 与会 专家 的 独家 点评 今天 为 大家 带来 的 推送 有 三个 部分 人类 基因组 编辑 国际 峰会 上 生物科技 生命 伦理 领域 科学家 就 基因 编辑 婴儿 ......
#
# seg_articles_delstp:  编者按 首例 基因 编辑 婴儿 事件 曝光 天 天内 整理 多个 可信 渠道 报道 点评 参加 贺建奎 第二届 国际 人类 基因组 编辑 峰会 公开 演讲 与会 专家 独家 点评 带来 推送 三个 人类 基因组 编辑 国际 峰会 生物科技 生命 伦理 领域 科学家 基因 编辑 婴儿 观点 第二届 人类 基因组 编辑 国际 峰会 组委会 发表 声明 组委会 接受 媒体 采访 内容 关注 回复 关键字 ......

# %% [markdown]
# 以上正文的展示省略了过多的内容。文档数量总共为48篇，分词后的文本以空格隔开词汇。接下来选取关键词，根据之前的计划，为了观察降维操作带来的影响，我们先不进行降维：

# %%
# n = -1意味着选取文档中出现的所有词汇
key_words_list = get_keywords(seg_articles_delstp, article_names, -1)
print('length: ', len(key_words_list), '\n')
print('key_words_list: ', key_words_list[:30], '......')
# Out:
# length:  12241
#
# key_words_list:  ['主力军', '嫌弃', '仙', '降级', '芙文', '下药', '手臂', '微盘', '行署', '惯例', '不起眼', '男同志', '独断', '哪来', '送交', '杂志', '应用领域', '行之君', '下为', '高庄', '防疟', '文化史', '黄海', '选项', '车祸', '未注明', '纸外', '人尽望', '牛马', '自古'] ......

# %% [markdown]
# 我们得到一万两千多个词汇，其中含有一定数量的生僻词。
#
# 下面计算TF-IDF，我们对标题赋予0.005的权重，令最小文档频率和最大文档频率分别为0、48，即不进行任何约束。

# %%
title_weight = 0.005
min_df = 0
max_df = 48
tfidf, key_words_upd = cal_tf_idf(seg_articles, article_names, key_words_list, title_weight, min_df, max_df)
print('shape: ', tfidf.shape)
# Out:
# shape:  (48, 12241)

# %% [markdown]
# ### 聚类

# %% [markdown]
# 经过以上过程，我们已经获得了描述文档的特征，即TF-IDF权重。接着根据特征的值进行聚类，把特征相似的文档归为一类，将特征不相似的文档归在不同类别中。
#
# 在这里，我们选用最简单的聚类算法，即K-means聚类。K-means聚类算法的原理是：随机选取类的中心点，根据样本点到中心点的距离将样本归类，然后定义同一类中所有样本点的重心为新的中心点，如此迭代直到中心点位置不发生显著的改变。这一算法是根据欧式距离计算样本点与样本点之间的距离，但我们的特征位于高维空间，并且特征向量的长度取决于文档长度等因素，为了避免这些因素的影响，应当用向量之间的夹角来描述文档相似度而并非直接计算欧氏距离。同时注意到两个向量的夹角和将它们归一化后再计算的空间距离存在一一对应的关系，换句话说，如果将所有的特征向量映射到单位球上，计算夹角与空间距离事实上是同一回事。所以在使用K-means算法之前，首先要对权重进行归一化。

# %%
# %%time
# 归一化权重
tf_idf_norm = normalize(tfidf)

# 选取合适的类别数量，这里经过尝试，我们选择10类
n_clusters = 10

# K-means
#为了得到相对可靠与稳定的结果，选择一个较大的n_init，这里用不同初始值重复2000次K-means算法，
labels = KMeans(n_clusters=n_clusters, n_init=2000).fit_predict(tf_idf_norm)
# Out:
# Wall time: 1min 27s

# %%
article_label = pd.Series(article_names, index=labels)
for label in range(n_clusters):   
    print('class ', label, ': ')
    if isinstance(article_label[label], str):
        print(article_label[label])
    else:
        for name in article_label[label]:
            print(name)
    print()
# Out:
# class  0 :
# 你说啥？寨卡疫情是转基因蚊子引起的？有没搞错啊！
# 别拿蚊子不当回事儿，它们的危害可不止让你痒得难受！
# 夏天被蚊子吸血很烦，那...蚊子也会感染病毒吗？
# 泰国登革热疫情爆发，国内这些地方也有感染风险！预防方法都在这
# 蚊子：我活不了，你也别想好过
#
# class  1 :
# 嫦娥是谁？广寒在哪？中秋怎么来？你啥也不懂，就知道吃月饼！
# 比起花样百出的月饼，我独爱月亮里温柔深沉的兔子
#
# class  2 :
# 7位科学家评基因编辑婴儿：不是对新知的探索，也没有医疗意义
# “基因编辑婴儿”出现后，设计一个“完美婴儿”离我们还有多远？ 热点
# “艾滋病免疫婴儿”诞生：基因编辑技术，为何成为争议的漩涡？丨热点
# 围绕“基因编辑婴儿”的荒诞剧，三百年前就已经上演了
# 接受基因疗法后，这个失去皮肤的“蝴蝶男孩”活了下来
# 贺建奎自称“借鉴了”权威伦理指南，但他一条也没遵守
#
# class  3 :
# 什么叫“外油内干”肤质啊？我到底该补水，还是该控油？
# 你刺痛过的脸，干燥过的皮，归根结底都是这个功能有问题
# 别整那些没用的！我只想要一支不作妖的防晒霜
# 别看有些护肤品成分简单，确是敏感肌的大救星！ 好物推荐
# 我要吹爆能卸妆的洗面奶，你们应该没有意见吧？
# 治痘痘只会玩儿命上猛药？不同等级的痘痘要用不同治疗方法你知道吗
# 白色情人节？别慌，回赠ta一片“海枯石烂”
#
# class  4 :
# 为什么中国专家不研究穿山甲？因为，早被吃没了
# 广东查获1.6吨穿山甲鳞片：徒有一身坚甲，难抵人类贪婪
# 提起“穿山甲”就想到“惨”？这9个萌点你必须得知道一下！
# 穿山甲：中国人的无知贪婪，让它们离灭绝一步之遥
#
# class  5 :
# 古代中国有没有入侵物种造成生态灾难的事情？
# 最后的盔犀鸟：这个活生生的物种，正一个个变成“工艺品”
# 珍稀棱皮龟惨遭屠宰，海龟保育之路任重道远
# 面对蝗灾，唐太宗选择了生！吞！蚂！蚱！
#
# class  6 :
# 今晚吃汤圆or吃元宵？这根本不是正月十五的重点好吗！
# 在沦落成“情人节”之前，古人的七夕比你们内涵多了
# 愚人节：不能忘记的中国传统节日！
# 甭管小年是二十三还是二十四，你们送上天的灶王都是个渣男
# 腊八：节日中的落难贵族？那是两大节日的合♂体！
# 重阳节是“灾日”吗？登高吃菊花就能长寿？茱萸又是谁？
# 鸡年将至，让我们来扒一扒鸡鸡的黑历史
#
# class  7 :
# 薯片、蛋卷和爆米花：人为什么喜欢酥脆的食物？
# 薯片炸鸡爆米花，你为啥喜欢嘎嘣脆的食物？
#
# class  8 :
# 一个灵敏的屁股有什么用
# 为啥科幻小说里的打打打都要拼动力？
# 你不懂换挡：在你销魂动作的背后，变速箱都忙活些啥？
# 你以为侠盗猎车手是那么好当的吗？保命要紧！
# 动力科技如何用1+1推动未来快进？
# 思铂睿混动油耗有多省？我们把车子开上五环实际挑战
#
# class  9 :
# “M型病毒”这个名字哪儿来的？病毒命名有什么规律？
# 世界艾滋病日：阻断HIV感染的黄金24小时
# 令人们谈之色变的艾滋病，是从哪来的？
# 病毒竟然也有免疫系统！为什么？因为怕被其他病毒感染
# 鹡鹚鹬鵙鹩鹛鹮鸺鹠鹪鹩䴙䴘——这都是些什么鸟字？

# %% [markdown]
# 我们发现，在同一类中存在的大多都是具有相似主题的文章，比如有关“基因编辑”的文章被归为同一类，同时还能发现其他主题，例如“寨卡病毒”、“汽车科技”、“传统节日”等。
#
# 同时我们发现一些文章被归到与期望不符的类别，例如对于类别9的“鹡鹚鹬鵙鹩鹛鹮鸺鹠鹪鹩䴙䴘——这都是些什么鸟字？”这篇文章，我们更希望将其归为类别5，因为这篇文章明显同类别中其他文章的“病毒”主题无关。
#
# 另外，类别与类别之间存在不均匀性，比如类别7的两篇文章高度相似，而类别5的文章虽然都涉及物种的问题，但具有不同的主题。
#
# 总体而言，本次聚类结果比较令人满意，虽然特征空间有一万多维（没有进行任何降维操作），但是K-means算法仍产生了大致准确的归类。接下来，我们尝试对特征空间进行降维。

# %% [markdown]
# ### 数据预处理 & 聚类 —— 降维后的结果

# %% [markdown]
# #### 特征选取

# %% [markdown]
# 对于每篇文档，选取频率前30的词汇作为关键词。可以看到关键词的数量明显下降——只有一千多个。

# %%
key_words_list = get_keywords(seg_articles_delstp, article_names, 30)
print('length: ', len(key_words_list), '\n')
print('key_words_list: ', key_words_list[:30], '......')
# Out:
# length:  1086
#
# key_words_list:  ['治', '蓝', '前', '祛痘', '汽车', '体细胞', '深沉', '干净', '吸', '进化', '配子体', '学', '哪来', '伦理', '蟾蜍', '组合', '龟', '农户', '动力', '文献', '行星', '翻', '记载', '找到', '我国', '化石', '事', '有害', '野生', '组委会'] ......

# %% [markdown]
# 去除在所有文档中出现次数过小或过大的词汇，规定下限为2，上限为30。关键词的数量又一次降低。
#
# 经过降维操作，特征数量从之前的一万多个下降为七百多个。

# %%
title_weight = 0.005
min_df = 2
max_df = 30
tfidf, key_words_upd = cal_tf_idf(seg_articles, article_names, key_words_list, title_weight, min_df, max_df)
print('shape: ', tfidf.shape)
# Out:
# shape:  (48, 719)

# %%
# %%time
tf_idf_norm = normalize(tfidf)
n_clusters = 10
labels = KMeans(n_clusters=n_clusters, n_init=2000).fit_predict(tf_idf_norm)
# Out:
# Wall time: 7.62 s

# %%
article_label = pd.Series(article_names, index=labels)
for label in range(n_clusters):   
    print('class ', label, ': ')
    if isinstance(article_label[label], str):
        print(article_label[label])
    else:
        for name in article_label[label]:
            print(name)
    print()
# Out:
# class  0 :
# 今晚吃汤圆or吃元宵？这根本不是正月十五的重点好吗！
# 在沦落成“情人节”之前，古人的七夕比你们内涵多了
# 愚人节：不能忘记的中国传统节日！
# 甭管小年是二十三还是二十四，你们送上天的灶王都是个渣男
# 腊八：节日中的落难贵族？那是两大节日的合♂体！
# 重阳节是“灾日”吗？登高吃菊花就能长寿？茱萸又是谁？
# 鸡年将至，让我们来扒一扒鸡鸡的黑历史
#
# class  1 :
# “M型病毒”这个名字哪儿来的？病毒命名有什么规律？
# 世界艾滋病日：阻断HIV感染的黄金24小时
# 令人们谈之色变的艾滋病，是从哪来的？
# 病毒竟然也有免疫系统！为什么？因为怕被其他病毒感染
#
# class  2 :
# 什么叫“外油内干”肤质啊？我到底该补水，还是该控油？
# 你刺痛过的脸，干燥过的皮，归根结底都是这个功能有问题
# 别整那些没用的！我只想要一支不作妖的防晒霜
# 别看有些护肤品成分简单，确是敏感肌的大救星！ 好物推荐
# 我要吹爆能卸妆的洗面奶，你们应该没有意见吧？
# 接受基因疗法后，这个失去皮肤的“蝴蝶男孩”活了下来
# 治痘痘只会玩儿命上猛药？不同等级的痘痘要用不同治疗方法你知道吗
#
# class  3 :
# 薯片、蛋卷和爆米花：人为什么喜欢酥脆的食物？
# 薯片炸鸡爆米花，你为啥喜欢嘎嘣脆的食物？
#
# class  4 :
# 你说啥？寨卡疫情是转基因蚊子引起的？有没搞错啊！
# 别拿蚊子不当回事儿，它们的危害可不止让你痒得难受！
# 夏天被蚊子吸血很烦，那...蚊子也会感染病毒吗？
# 泰国登革热疫情爆发，国内这些地方也有感染风险！预防方法都在这
# 蚊子：我活不了，你也别想好过
#
# class  5 :
# 一个灵敏的屁股有什么用
# 为啥科幻小说里的打打打都要拼动力？
# 你不懂换挡：在你销魂动作的背后，变速箱都忙活些啥？
# 你以为侠盗猎车手是那么好当的吗？保命要紧！
# 动力科技如何用1+1推动未来快进？
# 思铂睿混动油耗有多省？我们把车子开上五环实际挑战
#
# class  6 :
# 嫦娥是谁？广寒在哪？中秋怎么来？你啥也不懂，就知道吃月饼！
# 比起花样百出的月饼，我独爱月亮里温柔深沉的兔子
#
# class  7 :
# 7位科学家评基因编辑婴儿：不是对新知的探索，也没有医疗意义
# “基因编辑婴儿”出现后，设计一个“完美婴儿”离我们还有多远？ 热点
# “艾滋病免疫婴儿”诞生：基因编辑技术，为何成为争议的漩涡？丨热点
# 围绕“基因编辑婴儿”的荒诞剧，三百年前就已经上演了
# 贺建奎自称“借鉴了”权威伦理指南，但他一条也没遵守
#
# class  8 :
# 为什么中国专家不研究穿山甲？因为，早被吃没了
# 广东查获1.6吨穿山甲鳞片：徒有一身坚甲，难抵人类贪婪
# 提起“穿山甲”就想到“惨”？这9个萌点你必须得知道一下！
# 穿山甲：中国人的无知贪婪，让它们离灭绝一步之遥
#
# class  9 :
# 古代中国有没有入侵物种造成生态灾难的事情？
# 最后的盔犀鸟：这个活生生的物种，正一个个变成“工艺品”
# 珍稀棱皮龟惨遭屠宰，海龟保育之路任重道远
# 白色情人节？别慌，回赠ta一片“海枯石烂”
# 面对蝗灾，唐太宗选择了生！吞！蚂！蚱！
# 鹡鹚鹬鵙鹩鹛鹮鸺鹠鹪鹩䴙䴘——这都是些什么鸟字？

# %% [markdown]
# 同时，维度的减少也减少了K-means计算的时间，降维后的聚类结果仍然较为合理。说明选取的特征还是保留了主要用来区别文章的信息，在减少维度的同时也保证了聚类的准确性。

# %% [markdown]
# #### 转化为相似度矩阵

# %% [markdown]
# 在上一个小节，我们通过特征选取将关键词数量减少至将近5%，并同样得到了较为准确的聚类结果，但是此时对于48篇文章的小样本而言，特征空间还是有719维，远远大于样本数量。这说明，向量空间依然过于稀疏，我们希望进一步的处理，使得维度大小与样本数量接近或更小。
#
# 我们尝试将描写特征的权重改为相似度，也就是每篇文档的特征及它与其他文档的相似度，这时我们获得48 * 48的相似度矩阵，每一行描述一篇文档。这一做法直接使空间维度将至与文档数量相同的大小，防止“维度灾难”，于此同时，用相似度代表特征虽然丢失了文档本身关键词的信息，但是保留了文档之间的差别信息，仍然可以用来区分不同类型的文档。

# %%
# 先定义计算相似度的函数，注意计算的是余弦相似度
def cal_similarity(mtx):
    n_articles = mtx.shape[0]
    sim = np.zeros([n_articles, n_articles])
    mtx_length = ((mtx * mtx).sum(1)) ** (0.5)
    
    for i in range(n_articles):
        for j in range(i, n_articles):
            sim[i, j] = ((mtx[i] * mtx[j]).sum()) / (mtx_length[i] * mtx_length[j])
            sim[j, i] = sim[i, j]
    
    return sim

# %%
sim = cal_similarity(tfidf)
n_clusters = 10
labels = KMeans(n_clusters=n_clusters, n_init=2000).fit_predict(sim)

article_label = pd.Series(article_names, index=labels)
for label in range(n_clusters):   
    print('class ', label, ': ')
    if isinstance(article_label[label], str):
        print(article_label[label])
    else:
        for name in article_label[label]:
            print(name)
    print()
# Out:
# class  0 :
# “M型病毒”这个名字哪儿来的？病毒命名有什么规律？
# 世界艾滋病日：阻断HIV感染的黄金24小时
# 令人们谈之色变的艾滋病，是从哪来的？
# 病毒竟然也有免疫系统！为什么？因为怕被其他病毒感染
#
# class  1 :
# 古代中国有没有入侵物种造成生态灾难的事情？
# 最后的盔犀鸟：这个活生生的物种，正一个个变成“工艺品”
# 泰国登革热疫情爆发，国内这些地方也有感染风险！预防方法都在这
# 珍稀棱皮龟惨遭屠宰，海龟保育之路任重道远
# 白色情人节？别慌，回赠ta一片“海枯石烂”
# 面对蝗灾，唐太宗选择了生！吞！蚂！蚱！
# 鸡年将至，让我们来扒一扒鸡鸡的黑历史
# 鹡鹚鹬鵙鹩鹛鹮鸺鹠鹪鹩䴙䴘——这都是些什么鸟字？
#
# class  2 :
# 你说啥？寨卡疫情是转基因蚊子引起的？有没搞错啊！
# 别拿蚊子不当回事儿，它们的危害可不止让你痒得难受！
# 夏天被蚊子吸血很烦，那...蚊子也会感染病毒吗？
# 蚊子：我活不了，你也别想好过
#
# class  3 :
# 为什么中国专家不研究穿山甲？因为，早被吃没了
# 广东查获1.6吨穿山甲鳞片：徒有一身坚甲，难抵人类贪婪
# 提起“穿山甲”就想到“惨”？这9个萌点你必须得知道一下！
# 穿山甲：中国人的无知贪婪，让它们离灭绝一步之遥
#
# class  4 :
# 一个灵敏的屁股有什么用
# 为啥科幻小说里的打打打都要拼动力？
# 你不懂换挡：在你销魂动作的背后，变速箱都忙活些啥？
# 你以为侠盗猎车手是那么好当的吗？保命要紧！
# 动力科技如何用1+1推动未来快进？
# 思铂睿混动油耗有多省？我们把车子开上五环实际挑战
#
# class  5 :
# 今晚吃汤圆or吃元宵？这根本不是正月十五的重点好吗！
# 在沦落成“情人节”之前，古人的七夕比你们内涵多了
# 愚人节：不能忘记的中国传统节日！
# 甭管小年是二十三还是二十四，你们送上天的灶王都是个渣男
# 腊八：节日中的落难贵族？那是两大节日的合♂体！
# 重阳节是“灾日”吗？登高吃菊花就能长寿？茱萸又是谁？
#
# class  6 :
# 什么叫“外油内干”肤质啊？我到底该补水，还是该控油？
# 你刺痛过的脸，干燥过的皮，归根结底都是这个功能有问题
# 别整那些没用的！我只想要一支不作妖的防晒霜
# 别看有些护肤品成分简单，确是敏感肌的大救星！ 好物推荐
# 我要吹爆能卸妆的洗面奶，你们应该没有意见吧？
# 接受基因疗法后，这个失去皮肤的“蝴蝶男孩”活了下来
# 治痘痘只会玩儿命上猛药？不同等级的痘痘要用不同治疗方法你知道吗
#
# class  7 :
# 薯片、蛋卷和爆米花：人为什么喜欢酥脆的食物？
# 薯片炸鸡爆米花，你为啥喜欢嘎嘣脆的食物？
#
# class  8 :
# 7位科学家评基因编辑婴儿：不是对新知的探索，也没有医疗意义
# “基因编辑婴儿”出现后，设计一个“完美婴儿”离我们还有多远？ 热点
# “艾滋病免疫婴儿”诞生：基因编辑技术，为何成为争议的漩涡？丨热点
# 围绕“基因编辑婴儿”的荒诞剧，三百年前就已经上演了
# 贺建奎自称“借鉴了”权威伦理指南，但他一条也没遵守
#
# class  9 :
# 嫦娥是谁？广寒在哪？中秋怎么来？你啥也不懂，就知道吃月饼！
# 比起花样百出的月饼，我独爱月亮里温柔深沉的兔子

# %% [markdown]
# 用相似度描述特征的方法得到与之前类似的聚类结果，说明这一方法具有一定合理性。

# %% [markdown]
# #### PCA降维

# %% [markdown]
# 当样本数量很大时，转换为相似度的特征空间依然有着很高的维度，这时之前的方法均不能满足要求。因此，我们尝试采用PCA。
#
# PCA基于高维空间数据分布稀疏，所以必然导致一些维度是多余的思想，将数据投影到低维空间，并尽可能保持方差。下面的算法中，我们保留95%的方差，可以看到，新的维度为38维，小于样本数量。（事实上，PCA降维必然使得维度小于样本数量，因为n个样本点最多确定n-1维的空间。）

# %%
pca = PCA(n_components=0.95)
# 注意这里是用标准化之后的TF-IDF矩阵
tf_idf_pca = pca.fit_transform(tf_idf_norm)
cumsum = np.cumsum(pca.explained_variance_ratio_)
print(pca.n_components_)
# Out:
# 38

# %%
n_clusters = 10
labels = KMeans(n_clusters=n_clusters, n_init=2000).fit_predict(tf_idf_pca)

article_label = pd.Series(article_names, index=labels)
for label in range(n_clusters):   
    print('class ', label, ': ')
    if isinstance(article_label[label], str):
        print(article_label[label])
    else:
        for name in article_label[label]:
            print(name)
    print()
# Out:
# class  0 :
# 嫦娥是谁？广寒在哪？中秋怎么来？你啥也不懂，就知道吃月饼！
# 比起花样百出的月饼，我独爱月亮里温柔深沉的兔子
#
# class  1 :
# 为什么中国专家不研究穿山甲？因为，早被吃没了
# 广东查获1.6吨穿山甲鳞片：徒有一身坚甲，难抵人类贪婪
# 提起“穿山甲”就想到“惨”？这9个萌点你必须得知道一下！
# 穿山甲：中国人的无知贪婪，让它们离灭绝一步之遥
#
# class  2 :
# “M型病毒”这个名字哪儿来的？病毒命名有什么规律？
# 世界艾滋病日：阻断HIV感染的黄金24小时
# 令人们谈之色变的艾滋病，是从哪来的？
# 你不懂换挡：在你销魂动作的背后，变速箱都忙活些啥？
# 病毒竟然也有免疫系统！为什么？因为怕被其他病毒感染
# 白色情人节？别慌，回赠ta一片“海枯石烂”
# 鸡年将至，让我们来扒一扒鸡鸡的黑历史
#
# class  3 :
# 你说啥？寨卡疫情是转基因蚊子引起的？有没搞错啊！
# 别拿蚊子不当回事儿，它们的危害可不止让你痒得难受！
# 夏天被蚊子吸血很烦，那...蚊子也会感染病毒吗？
# 泰国登革热疫情爆发，国内这些地方也有感染风险！预防方法都在这
# 蚊子：我活不了，你也别想好过
#
# class  4 :
# 什么叫“外油内干”肤质啊？我到底该补水，还是该控油？
# 你刺痛过的脸，干燥过的皮，归根结底都是这个功能有问题
# 别整那些没用的！我只想要一支不作妖的防晒霜
# 别看有些护肤品成分简单，确是敏感肌的大救星！ 好物推荐
# 我要吹爆能卸妆的洗面奶，你们应该没有意见吧？
# 接受基因疗法后，这个失去皮肤的“蝴蝶男孩”活了下来
# 治痘痘只会玩儿命上猛药？不同等级的痘痘要用不同治疗方法你知道吗
#
# class  5 :
# 一个灵敏的屁股有什么用
# 为啥科幻小说里的打打打都要拼动力？
# 你以为侠盗猎车手是那么好当的吗？保命要紧！
# 动力科技如何用1+1推动未来快进？
# 思铂睿混动油耗有多省？我们把车子开上五环实际挑战
#
# class  6 :
# 今晚吃汤圆or吃元宵？这根本不是正月十五的重点好吗！
# 在沦落成“情人节”之前，古人的七夕比你们内涵多了
# 愚人节：不能忘记的中国传统节日！
# 甭管小年是二十三还是二十四，你们送上天的灶王都是个渣男
# 腊八：节日中的落难贵族？那是两大节日的合♂体！
# 重阳节是“灾日”吗？登高吃菊花就能长寿？茱萸又是谁？
#
# class  7 :
# 古代中国有没有入侵物种造成生态灾难的事情？
# 最后的盔犀鸟：这个活生生的物种，正一个个变成“工艺品”
# 珍稀棱皮龟惨遭屠宰，海龟保育之路任重道远
# 面对蝗灾，唐太宗选择了生！吞！蚂！蚱！
# 鹡鹚鹬鵙鹩鹛鹮鸺鹠鹪鹩䴙䴘——这都是些什么鸟字？
#
# class  8 :
# 薯片、蛋卷和爆米花：人为什么喜欢酥脆的食物？
# 薯片炸鸡爆米花，你为啥喜欢嘎嘣脆的食物？
#
# class  9 :
# 7位科学家评基因编辑婴儿：不是对新知的探索，也没有医疗意义
# “基因编辑婴儿”出现后，设计一个“完美婴儿”离我们还有多远？ 热点
# “艾滋病免疫婴儿”诞生：基因编辑技术，为何成为争议的漩涡？丨热点
# 围绕“基因编辑婴儿”的荒诞剧，三百年前就已经上演了
# 贺建奎自称“借鉴了”权威伦理指南，但他一条也没遵守

# %% [markdown]
# 采用PCA降维的结果依然较为合理。

# %% [markdown]
# ### 小结

# %% [markdown]
# 以上我们采用了四套方法，下面将它们列举出来：
#
# 1. 选用所有文档的所有非停用词汇作为关键词。维度大小：12241。
# 2. 选用每篇文档频率前30的词汇作为关键词，并去除DF值过小或过大的词汇。维度大小：719。
# 3. 在 2 的基础上计算文档与文档的相似度，用相似度代替权重。维度大小：48。
# 4. 在 2 的基础上采用PCA降维。维度大小：38
#
# 结果显示，三种降维处理的方式均能产生合理的聚类结果。而降维效果则是特征选取+PCA的方式最优。

# %% [markdown]
# ## 大样本处理

# %% [markdown]
# 接下来进行大样本的处理，对于样本数量为几百几千的情况，由于关键词数量随着文档数量增加而增加，特征空间也会有较高的维度。根据我们之前在小样本上实验的结果，为了尽可能地减少空间，采用特征选取+PCA的降维方法。

# %% [markdown]
# ### 数据导入

# %% [markdown]
# 我们从已知的历史文章网址中获取html页面，并从页面中提取所需的文本数据。

# %%
def extract_content(url):
    
    # 根据url地址提取正文内容
    
    res = requests.get(url)
    res.encoding = 'utf-8'
    soup = BeautifulSoup(res.text, 'lxml')
    content = soup.select('#js_content')
    
    article_str = ''
    for i in range(len(content)):
        article_str += content[i].text
        
    return article_str

# %%
# 有关微信公众号文章信息的内容均储存于"guokr_articles.csv"文件中
# 读取文件
f = open('guokr_articles.csv', 'rb')
df = pd.read_csv(f)
f.close()
# 选择最近的1000篇文章作为数据
articles_df = df.loc[9180:, ['时间', '标题', '文章链接']]
n_articles = articles_df.shape[0]
articles_df.index = range(n_articles)

# %%
# 定义文档数据存放路径
articles_path = r'F:\\guokr_articles\\'

# %% [raw]
# for idx in range(len(articles_df)):
#
#     url = articles_df.loc[idx, '文章链接']
#     article = extract_content(url)
#     article = article.encode('utf-8')
#     title = articles_df.loc[idx, '标题']
#     title = title.replace('/', '')
#     title = title.replace('|', '')
#     title = title.replace('?', '')
#     filename = str(title) + '.txt'
#
#     with open(articles_path + filename, 'wb') as f:
#         f.write(article)

# %% [markdown]
# ### 数据预处理 & 数据分析

# %% [markdown]
# 以下内容与小样本上的处理流程相同。

# %%
# 存放文章标题
article_names_full = []
# 存放原始文本内容
article_texts_full = []
# 存放分词后的文本内容
seg_articles_full = []
# 存放分词、去停用词后的文本内容
seg_articles_delstp_full = []

# 一一读取目录中的文档
for fname in os.listdir(articles_path):
    article = open(os.path.join(articles_path, fname),'r',encoding='utf-8').read()
    
    article_name = fname.replace('.txt', '')
    article_names_full.append(article_name)
    
    article_text = article.replace('\n', '')
    article_texts_full.append(article_text)
    # 分词
    article_seg_list = jieba.lcut(article_text)
    
    seg_text = ''
    seg_text_delstp = ''
    
    for word in article_seg_list:
        if is_chinese(word):
            seg_text += word + ' '
            if word not in stopwords_list:
                seg_text_delstp += word + ' '
                
    seg_articles_full.append(seg_text)
    seg_articles_delstp_full.append(seg_text_delstp)

# %%
n_articles_full = len(article_names_full)
print('n_articles: ', n_articles_full, '\n')
print('article_names: ', article_names_full[0], '\n')
print('article_texts: ', article_texts_full[0][:200], '......', '\n')
print('seg_articles: ', seg_articles_full[0][:200], '......', '\n')
print('seg_articles_delstp: ', seg_articles_delstp_full[0][:200], '......', '\n')
# Out:
# n_articles:  1000
#
# article_names:  &quot;毒书皮&quot;卷土重来，强致癌、或致儿童性早熟？
#
# article_texts:  又到了一年一度的开学季，新一轮的“包书皮大战”也拉开了序幕，正所谓“举头望明月，低头包书皮”，“洛阳亲友如相问，我在家中包书皮”。近年来，塑料包书皮因其样式繁多、图案鲜艳，兼具防水、耐磨、防污染的功能，备受广大中小学生青睐。但最近网上有消息称，这些美丽夺目的包书皮很可能含有致癌性的多环芳烃和导致性早熟的邻苯二甲酸酯…… 2015 年，“毒书皮事件”火遍网络。物理系毕业的魏先生盯着女儿的包书皮，怎么 ......
#
# seg_articles:  又 到 了 一年一度 的 开学 季 新一轮 的 包书皮 大战 也 拉开 了 序幕 正 所谓 举头 望明月 低头 包书皮 洛阳 亲友 如相问 我 在 家中 包书皮 近年来 塑料 包书皮 因 其 样式 繁多 图案 鲜艳 兼具 防水 耐磨 防污染 的 功能 备受 广大 中小学生 青睐 但 最近 网上 有 消息 称 这些 美丽 夺目 的 包书皮 很 可能 含有 致癌性 的 多环 芳烃 和 导致 性早熟 的 ......
#
# seg_articles_delstp:  一年一度 开学 季 新一轮 包书皮 大战 拉开 序幕 正 举头 望明月 低头 包书皮 洛阳 亲友 如相问 家中 包书皮 塑料 包书皮 样式 繁多 图案 鲜艳 兼具 防水 耐磨 防污染 功能 备受 中小学生 青睐 网上 消息 称 美丽 夺目 包书皮 含有 致癌性 多环 芳烃 导致 性早熟 邻苯二甲酸 酯 年 毒 书皮 事件 火遍 网络 物理系 毕业 魏先生 盯 女儿 包书皮 闻 一股 刺鼻 臭味儿  ......

# %%
key_words_list_full = get_keywords(seg_articles_delstp_full, article_names_full, 30)
print('length: ', len(key_words_list_full), '\n')
print('key_words_list: ', key_words_list_full[:30], '......')

title_weight = 0.005
min_df = 2
max_df = 800
tfidf_full, key_words_upd_full = cal_tf_idf(seg_articles_full, article_names_full, key_words_list_full, title_weight, min_df, max_df)
print('shape: ', tfidf_full.shape, '\n')

tf_idf_full_norm = normalize(tfidf_full)
pca = PCA(n_components=0.95)
# 注意这里是用标准化之后的TF-IDF矩阵
tf_idf_full_pca = pca.fit_transform(tf_idf_full_norm)
print('pca components: ', pca.n_components_)

n_clusters = 200
labels_full = KMeans(n_clusters=n_clusters, n_init=200).fit_predict(tf_idf_full_pca)

article_label_full = pd.Series(article_names_full, index=labels_full)
for label in range(n_clusters):
    print('class ', label, ': ')
    if isinstance(article_label_full[label], str):
        print(article_label_full[label])
    else:
        for name in article_label_full[label]:
            print(name)
    print()
# Out:
# length:  11912
#
# key_words_list:  ['引脚', '仙', '年份', '治死', '视觉', '扫描', '心绞痛', '甘纳许', '扭蛋里', '手臂', '屯', '香螺', '颈椎病', '不起眼', '纸币', '熟醉蟹', '水晶球', '哪来', '杂志', '课程', '生成', '空间站', '吃糖', '选项', '车祸', '手气', '一毛钱', '姬', '进化论', '说唱'] ......
# shape:  (1000, 9666)
#
# pca components:  843
# class  0 :
# 休斯顿，我们的空间站被砸漏了！用胶带粘粘能行吗  迈向太空
# 俄罗斯最可靠的火箭出故障了！宇航员险些丧生
# 再见，大钟！我国新一代载人飞船重磅亮相，目标直指载人登月
#
# class  1 :
# 10次雨果奖、7次星云奖、4次轨迹奖。顶尖科幻大师解构“时间”  好物推荐
# 刘慈欣获克拉克奖，这个奖可能⽐任何奖都重得多
# 韩松：科幻预言超级消费时代丨有意思博物馆
#
# class  2 :
# 下周一就是教师节？别急，礼物已经挑好了！ 好物推荐
# 丝巾怎么系，才能美美哒？ 好物推荐
# 在大阪，享受美食一定要去这个地方  好物推荐
# 江湖救急！距离七夕只剩5天，现在挑礼物还来得及
# 身价N个亿的大佬们，退休后坐拥金山会干啥？
#
# class  3 :
# 一份连环杀手的占星解读，让94%的受访者看到了自己
# 为了证明太阳小时候很熊，我们找遍了它的“三姑六婆” 迈向太空
# 太阳系或有第九行星，比地球还大？新天体的发现再添线索  迈向太空
# 帕克号：种不成太阳，那还可以摸它呀！ 迈向太空
# 飞出太阳系！旅行者探测器将飞往何处？
#
# class  4 :
# “妈，求你别再转发这种文章了”，中老年人为何成为网络谣言重灾区？
# 你家宝宝为什么总是吃手手？可不是为了卖萌
# 健身网红挺着大肚子运动，婆婆却叫我老实躺着，我究竟该听谁的？ 过日子
# 喘不上气，还拿纸袋罩住脸？可能真的有用！
# 在网上，没人在意你120岁
# 我国有2.1亿人的健康，被”沉默的杀手“控制
# 有一种痛，让人彻底告别啤酒和海鲜，它的名字叫痛风  过日子
# 有的人活着，但他的颈椎已经快死了……
# 爱运动的老人家们，健身不能光顾着动作酷炫啊！丨过日子
# 老人可能不是真耳背，而是这个小问题造成的
# 脊柱里装上小电脑，或许可以让瘫痪者重新站起来！
# 运动有辣么多好处，而你却只看重&quot;减肥&quot;这一项  好课推荐
# 面基库里，听他说说逆天三分是怎样练成的
#
# class  5 :
# “让肠道动起来”，酸奶中的益生菌真有这么神奇？
# 传说中的食品工业添加剂，竟然长得这么美？
# 还在吐槽国内食品？外国人忽悠起来才是可怕！
# 量产甜蜜：为什么我们无法停止吃糖和变胖？丨深度
#
# class  6 :
# “爸爸，老师布置了一道家庭作业，要你和我一起数1亿粒米。”
# 人在渴死的过程中，都发生了什么？
# 你在浪费粮食，科学家却在用垃圾制作美食
# 北极常年不见人，哪儿来的这么多垃圾？
# 垃圾鲨鱼：专“吃”海上垃圾，一次吃掉360斤！
# 我同意建垃圾焚烧厂，但别建在我家附近 ——这个死结有解吗？
# 自动驾驶船舶扬起了帆，海上无人模式指日可待
# 艺术家又来逗你玩了：这些瑰丽名画，都是垃圾做的
# 长得像个锤子还爱吃素，这种鲨鱼堪称鲨中之耻！
#
# class  7 :
# 我尝过最可怕的食物，是带着血味的果冻  AI夜话
# 我的心怎么跟烧着了一样？“烧心”到底烧的哪儿？ 过日子
# 鱼刺卡喉，吞饭团灌醋都没用！还是医生取刺最靠谱  过日子
#
# class  8 :
# 今日《自然》重磅：抗癌居然如此简单？科学家们发现口服甘露糖可以显著抑制肿瘤生长！
# 光吃不胖的方法，科学家们还真的找到了
# 别浪费了自己的潜在技能，你其实很能跑的！
# 嗜辣如命？你吃辣可能比不上这个小家伙
# 有一种小鼠，生活得锦衣玉食，但你可能并不了解ta
# 熊孩子长大后，都去实验室称霸天下了！
# 让两个爸爸生娃？中国科学家又搞大事啦！
#
# class  9 :
# &quot;毒书皮&quot;卷土重来，强致癌、或致儿童性早熟？
# “咸鱼”都比你有志向！几亿年前它们为了远方而走出海洋！
# 《延禧攻略2》可以这样拍吗？
# 人体内发现微塑料？不仅侵入血液、肝脏等，它还有哪些危害？  热点
# 伟哥本来是治疗心绞痛的？它们的发现都是美丽的意外
# 南极惊现方块冰山！难道是外星人切割的？
# 外卖不再现做，改用方便菜肴包，那还能吃吗？
# 放进烤箱就能做的小挂件，热缩片太好玩了！
# 文具盒里的狗血CP：为什么橡皮总爱粘尺子？
# 晕了晕了，这么多鱼都叫鳕鱼，到底哪个是真的？哪个能给孩子吃？
# 海底浓烟滚滚？别慌，这是遇见宝贝啦
# 说到签证问题，亚非科学家都是泪
#
# class  10 :
# 10件著名的假古董，和买下它们的冤大头
# 【明日开馆】去「有意思博物馆」见姬十三、河森堡、张双南……
# 一道来自比尔·盖茨的“面试题”：猜猜姬十三的答案？
# 不打扮还算人吗？闪闪发光的饰品如何造就人类
# 世界各地的恶心食物都在这里了：你能忍到第几级？
# 为什么说潘家园是中国最大的露天博物馆
# 今年体检各种指数又不正常了？除了健身我们还能做些啥？
# 博物馆被毁，我们能知道自己失去了什么吗？
# 周雪：如何制作一件隐身衣？ 有意思博物馆
# 大揭秘！“有意思博物馆”最全攻略  果壳年度重磅活动
# 如果这座博物馆没有着火，2000万件文物的救命钱下个月就到账了  热点
# 想要吃得健康，就得善用拳头  有意思博物馆
# 有意思博物馆48小时，我们迎接了28957个有意思的人
# 来自肠胃病学家的真人测评：坐着做肠镜，so easy
# 果壳年度最重磅活动来袭！一场“科技与博物”的异想狂欢
# 没想到，拯救了我人生的，竟然是扭蛋
# 这个负责帮你赚钱减肥谈恋爱的地方，免费了
# 通往文创世界的任意门，等你开启！
# 逮谁摔谁的自行车，诚邀您试驾！
#
# class  11 :
# “厕所闹革命”，到底要革谁的命？
# 一考试就拉肚子，吹空调也拉肚子，我这是怎么了？ 过日子
# 厕所厨房的小虫子都叫啥？除了狂喷杀虫剂还有啥办法？
# 拉屎压水花，科学吃便便？这场演讲活动很重口
# 粑粑去哪了，咱们聊个有味道的话题吧
#
# class  12 :
# 冬天来了，你一定穿了秋裤，而我却脱掉了“毛裤”
# 头秃青年们的福音：请收下这份治脱发大全！
# 长在头上是骄傲，长在腋下是烦恼，双标的人类啊
#
# class  13 :
# 20位著名科学家评贺建奎：用孩子的健康和希望换取廉价噱头，简直卑鄙！
# 《生活习惯简史》回归，第9册强势首发！陪孩子读书看世界  好物推荐
# 一篇概括三本育儿书：教你怎么和孩子说话
# 他是史上最能生的男人，一生拥有888个孩子
# 养猫的人更健康，没猫的孩子像根草？真相比这更扎心
# 别让&quot;更喜欢爸爸or妈妈&quot;毁掉孩子的情商丨好课推荐
# 娃才上一年级，让你怀疑人生的数学题已经来了
# 影响智力又毁颜值，宝宝打鼾千万要重视
# 我给孩子留下了10亿元的遗产，没想到......  好课推荐
# 明星们，别让孩子配合你们演出那些情节了……
# 李一诺：一米高度看世界丨有意思博物馆
#
# class  14 :
# 一双可盐可甜的经典百搭小白鞋，帮你搞定10套look！  好物推荐
# 双十一促销套路多的脑壳疼！直接降价不好吗？！  好物推荐
# 国庆优惠，活儿姐来撒优惠券  美丽店铺
# 大风降温时，我才注意到自己有多需要这款神器  好物推荐
# 我要吹爆能卸妆的洗面奶，你们应该没有意见吧？
# 有设计感的基本款，这样的内衣好穿又独特  好物推荐
# 没想到失眠又秃头的90后，背着80后先用上眼霜了......  好物推荐
# 现在买东西门槛都这么高的吗？不光烧钱还烧脑啊！ 好物推荐
# 肩颈酸痛想按摩，马杀鸡又太贵，这个东西让人很心动！ 好物推荐
# 自打用上这个过冬神器，隔壁同事坐得离我越来越近了！ 好物推荐
#
# class  15 :
# 为了在寒冬温暖你，你不知道棉花有多努力
# 别整那些没用的！我只想要一支不作妖的防晒霜
# 我的假期计划，是自己在家做棉花糖
#
# class  16 :
# 11月吃货囤货节，卖完这波儿所长就去抢救了......
# 什么？茅台做的醉蟹竟然有限时优惠，两盒立省50元！ 好物推荐
# 吃过《风味人间》里最馋人的美食后，他竟然打了个差评......｜好物推荐
# 被人上锅煎炸烹煮的大闸蟹，会疼吗？
# 颠覆你想象的“棋子蟹”：没想到小小的居然也黄肥膏满呢！好物推荐
#
# class  17 :
# 想要轻松燃烧卡路里？玩会儿游戏就能做到丨好物推荐
# 想要轻松燃烧卡路里？玩会儿游戏就能做到！ 好物推荐
# 想要轻松燃烧卡路里？玩会儿游戏就能做到！冬季健身必备   好物推荐
#
# class  18 :
# 你真的会用手机拍照吗 ？ 好课推荐
# 因为太会说，他这一辈子从没失败过  好课推荐
# 如何在的景点里拍出惊艳的照片？ 好课推荐
# 安卓十岁了，它如何逆袭成全球最多人用的手机系统？
# 我升职了，却想辞职  好课推荐
# 抖音里的土味高科技，在非洲比比皆是
# 敦煌终将不复存在，但我们能让它代代相传
# 明明玩手机时的我全神贯注，怎么还说手机让人多动症呢？
# 熬夜拖延懒得动？是手机先动的手！
# 用一张A4纸，做一个神奇的错觉视频！
# 直男别走：一秒上手的P图指南
#
# class  19 :
# 世界上第一口啤酒是被哪个幸运儿喝掉的？
# 啤酒到底苦不苦，你说了不算，成分说了算！
# 小姐姐打碎了一杯草莓味儿啤酒，隔壁办公室的同事都馋哭了  好物推荐
#
# class  20 :
# 5G啊5G，你是不是只比4G多一G？
# 为什么每天这么多负面新闻，我的同情心都快被耗尽了  深度
# 你和世界，我想一起守护
# 真的猛士，敢于让别人直面自己的手机
# 离开手机，你还是你吗？新技术如何塑造了我们？
# 秀恩爱，给主播花钱，AA付账，我一个社会学者，为什么要研究这些玩意儿？
# 这对搞垮热搜的夫妇，唯一一次秀恩爱就是领证
#
# class  21 :
# 120年前，那一场风花雪月、风起云涌的怪病
# 7位科学家评基因编辑婴儿：不是对新知的探索，也没有医疗意义
# “基因编辑婴儿”出现后，设计一个“完美婴儿”离我们还有多远？ 热点
# “艾滋病免疫婴儿”诞生：基因编辑技术，为何成为争议的漩涡？丨热点
# 你的博士论文交了吗？别忘了，完成比完美更重要
# 冤有头债有主，把我绑在公司的这些办公用品都是谁发明的！
# 发了顶级论文，却被官方跨国手撕，他们摊上什么事儿了？
# 围绕“基因编辑婴儿”的荒诞剧，三百年前就已经上演了
# 大象活到70也不患癌？因为体内有个“僵尸基因”
# 如果你成为了医学实验的&quot;对照组&quot;
# 年薪十万在国际上属于什么水平？
# 招人啦！揭秘与AI共事的果壳员工日常，他们竟然过着这样的日子
# 换个季而已，这个兔几怎么变得连亲妈都不认识了！
# 欧盟越来越保守？基因修饰作物新规一出，科学家们都炸了
# 由于研究对象过于可爱，这群研究者的项目压力很大
# 警告：智商1000的人，即将来到人间
# 这些星二代，一看就是亲生的！
# 这种神奇动物，不用喂食，晒晒太阳就行，可是……
# 香甜好喝的牛奶，对于以前的成年人来说，竟是一种毒药？
#
# class  22 :
# 厨房生存：你炸翻了天，她摆好了盘  AI夜话
# 我们村流传吃猪蹄跛脚，坑得我二十好几才啃上第一口猪蹄儿  AI夜话
# 鸡脖鸡翅鸡屁股，鸡身上到底哪里不能吃？
#
# class  23 :
# 6张科学美图，你能猜出来他们是谁吗？
# “花钱”进化论？宇宙烟花？这么好玩的博物馆式演讲你绝对没听过！
# 中国古代人用什么仰望星空？牛到超乎你想象 有意思博物馆
# 为什么光这么牛？看看光有多努力就知道了
# 互联网时代下的科技传播，你会吗？
# 你我皆凡人，大家都有病丨有意思博物馆
# 你看到的闪蝶标本，可能都是做过“切腹手术”的
# 冀连梅：我们应该怎样用药丨有意思博物馆
# 就等你了！果壳少年编委第二期招募正式启动
# 带上你的好奇心和想象力，和科学家们一起迈向宇宙深处
# 翼狼Elang：给宅人的动物行为学入门指南  有意思博物馆
# 骆琦：带着两个baby环游世界是怎样的体验？丨有意思博物馆
#
# class  24 :
# “我和同学之间，是纯洁的金钱关系。”
# 一条咸鱼如何在21天内挣到34900元？
# 为什么说戒断碳水不能用来减肥？ 过日子
# 人生失控了才会只靠节食来减肥  好课推荐
# 你的时间非常值钱：把1天过成48小时有可能吗  好课推荐
# 别自己骗自己了，根本就没有健康的肥胖
# 原来世界上真有解忧杂货铺，就在这里
# 天天聚餐怎么减肥啊？别急，4招教你做一只健康的吃货
# 我赌50块，你一件事坚持不了21天
# 生酮饮食到底是什么神仙科技，炸鸡烤肉照吃不误真能减肥吗？
# 看了这几个减肥的真相，突然觉得这些年都白减了
# 看过BBC解剖200斤的遗体，你会想用生命开始减肥  好课推荐
#
# class  25 :
# 伤口结痂后，痒到怀疑人生却不敢挠！还有别的办法吗？
# 小伤口处理不好险丢命！破伤风是个什么病？
# 打哈欠、放屁、打嗝……这些让人尴尬的本能到底是干啥用的啊
# 看到别人挠痒痒，你也觉得痒？挠痒痒会传染吗？
#
# class  26 :
# “转”出一个新世界——转基因科普大赛启动仪式邀你参加！
# 从科学角度看，《黑龙江日报》非转基因大豆专题报道究竟错在哪？
# 你新拔草的爱豆同款，很有可能是转基因的
# 公众为什么质疑转基因？
# 大家都是成年人，该懂点生活了，快试试这个游戏提升一下
# 正式“转”起来！转基因科普这么久，这次你来！
#
# class  27 :
# 半路出家学化学，结果得了诺贝尔奖，乳腺癌都打不倒的硬核人生
# 又是乳腺癌！《樱桃小丸子》作者因它去世，这个病有多可怕？
# 钢圈bra真的会导致乳腺癌吗？男性也会得乳腺癌？这篇文章给你解释
#
# class  28 :
# “双十一”你们累坏了多少快递员！是时候考虑一下仓库机器人了
# “机器猫”陪着你，你会变成学霸吗？
# “机器皮肤”魔法来袭，你随便捏个纸团都能化身行走机器人
# 仅用直线画出逼真爱因斯坦，直线就是这么无所不能！
# 从古希腊到西部世界：人类三千年的机器人情结
# 他开发了一款模拟父亲语气的聊天AI，还没做完人就抑郁了……
# 会挑眉卖萌、眉目传情，日本出萌妹子机器人啦！
# 全球最没用机器人都在这里了，我选择会拉屎的这一款
# 哈佛水下机器人，花瓣手温柔捕获海底生物
# 啊啊啊，这些机器人也太萌了吧，想拥有！
# 想装机器手，你现在有5种选择了，快来挑一个！
# 报警啦！他家私藏了一只蹦蹦猴，哦不，蹦蹦机器人
# 有眼疾，让这群小小小机器人游进你眼睛里帮你上药呗
# 机器人：为什么我们非得是白色的？
# 终于出了一款我们买得起、还能自己撸的机器猫了！
# 能爬墙的软体机器人，无需编程基础也可以玩
#
# class  29 :
# 明明一点甜食都没碰，怎么还是吃进去了这么多糖？
# 甜虾这么美味，果然是女装男孩子没有错
# 虾究竟犯了什么错，要“赎罪”？ 好物推荐
# 超好吃的潮汕海鲜粥，秘诀是这个步骤！
# 马达加斯加的海是什么味道？吃个虾就知道了！ 好物推荐
#
# class  30 :
# 2018年最后的自我提升，全靠这张图了   好课推荐
# 99%靠着直觉生活的人，都得不到想要的人生  好课推荐
# 99%靠着直觉生活的人，都得不到想要的人生
#
# class  31 :
# “你那么厉害咋不上天呢？那我就上给你看”——梦想是要有的，且一定会实现
# 为什么武侠小说里面总喜欢双剑合璧？
# 如何科学地向你妈说明小孩子也是有“腰”的
# 我哼着歌，开着车，等着红灯……怎么又浪费油了？
#
# class  32 :
# 以色列政府决定毒死一半胡狼，后果谁也没有想到
# 原子弹？不，冷战时美国最怕的其实是脊髓灰质炎
# 有人说狂犬疫苗大量浪费，中国人打狂犬疫苗真的太多了吗？
# 花小钱办大事——肺炎球菌疫苗，对宝宝的天敌说不！
# 被猫狗鼠兔、蝙蝠狐狸咬过，我成了防疫站VIP会员  AI夜话
#
# class  33 :
# 又双叒叕要下雨了？你需要这把淋不湿的伞！  荐物
# 用了这么多年的雨伞，还不如一片荷叶厉害？
# 秋雨绵绵，你需要一把用后立干的伞  好物推荐
# 距离雨天好心情，你只缺一把淋不湿雨伞  好物推荐
#
# class  34 :
# 中秋吃月饼，伤牙怎么办？教你1分钟守护牙齿健康  好物推荐
# 如果你家已经有洗衣机了，我推荐你买把电动牙刷试试  好物推荐
# 我和这把电动牙刷的故事，始于颜值  好物推荐
# 牙膏止血？改善口腔健康才是关键啊朋友！丨好物推荐
# 牙龈出血是缺维生素吗？天真！
# 电动牙刷要是还能洗脸，这波操作岂不是赚大了？ 好物推荐
#
# class  35 :
# 15年来最大尘暴终于开始衰退，机遇号能醒过来吗？
# 快醒来啊机遇号！不然45天之后NASA就不要你了！ 迈向太空
#
# class  36 :
# 内有福利：今年双11，跟着AI一起剁手呀
# 掉头发不是喝水的锅，这些才是......
#
# class  37 :
# AI不能创造艺术？它正在让艺术重获新生
# 你眼中的破铜烂铁，被72岁老爷子做成了会动的艺术品！
#
# class  38 :
# 6大“月球之谜”，看看你能猜中几个？
# 奇葩作业又来了？让孩子观察月亮，家长每天半夜代劳丨0分作业
# 好奇号Pro：Mars 2020 将会去哪里？
# 宇宙穷游指南：曙光号花最少的钱，看最精彩的世界  迈向太空
# 我们的月亮，原来真的是枚“水冰月”！ 迈向太空
# 抛10次硬币都是正面朝上，那第11次呢？
#
# class  39 :
# 你坚持最久的一件事是什么？这次帮你破纪录！丨好物推荐
# 重要通知！限定版物种插画只送不卖！错过就真的没有了！
#
# class  40 :
# 听说你也是收藏癖？是时候把整个大自然收回家了  好物推荐
# 流行颜色+精致兰花，给你100页自然角落  好物推荐
# 科学青年的年终囤货，也是要看颜值的  好物推荐
#
# class  41 :
# 一键上太空！最不务正业的NASA出了个自拍神器
# 去了一次天文台，我决定辞职去学天体物理
# 哈勃望远镜不好使了怎么办？答：打一顿就好了  迈向太空
# 这些美美的照片都离不开它，明天斯皮策就满15岁啦
#
# class  42 :
# 三岁小朋友都有自己的显微镜，你呢？ 好物推荐
# 你和梦想之间就差400万零花钱？收下这份双11科学剁手指南，省钱过上神仙人生不是梦  好物推荐
# 双11放血计划偷跑！果壳商店人气单品直降！鲸为天人大吃一鲸  好物推荐
# 史无前例大特惠，人气T恤5折起！ 好物推荐
# 泄密！爆品直降、跨店满减、低至5折！果壳内部员工剁手清单流出，公式都帮你写好了  好物推荐
# 科学青年的双11剁手清单！果壳商店全年最低价，手慢无丨好物推荐
# 限时优惠！屯一批文具（假装）迎接新学期  好物推荐
#
# class  43 :
# 为啥看什么都好像打了码？因为你没擦干净屏幕啊！ 好物推荐
# 保湿细节要到位！随手喷一喷+涂一涂，你就比别人精致100倍  好物推荐
# 出门旅行，化妆品要这样带，才不会被机场没收！
# 别看有些护肤品成分简单，确是敏感肌的大救星！ 好物推荐
# 自打入秋开始就脸部拔干，这张老脸还有救吗？ 好物推荐
#
# class  44 :
# 什么，生巧居然不是巧克力？
# 从苦瓜到苦菊，人类为什么这么喜欢“自讨苦吃”？
# 做麦片呢，就是压一压、挤一挤、烤一烤……
# 听说有种巧克力，想吃得用锤子敲！ 好物推荐
# 新鲜可可果竟是山竹味！为了变成巧克力，它都经历了些什么
# 爆卖10000盒的榴莲千层限时放血优惠，只剩最后5天，手慢无！ 好物推荐
#
# class  45 :
# 有了这个技术，你在户外戴着耳机听歌会更安全  好物推荐
# 耳机一般不会影响听力，为什么还是不能戴太久？
# 这技术能让你在户外听歌更安全  好物推荐
#
# class  46 :
# 好！翻着花样地好！对新产品异常自信的苹果，再次被科技媒体狠狠吐槽
# 苹果新品没让人失望！但这些旧产品，曾让人一言难尽丨热点
#
# class  47 :
# 七夕在老黄历里是“分手节”，怎么现在成了情人节？
# 你为什么单身？14个理由中，“肥”和“宅”连前5都挤不进去  七夕
# 做了几个网红化学实验，结果……一言难尽
# 心在滴血是什么样的？今天特别适合了解一下丨七夕
# 找对象的区块链都有了，你怎么还单身？丨七夕
#
# class  48 :
# 打耳洞这种“小事”，找医生打是什么感觉？
# 野蛮、习俗、成长：人们为什么打耳洞？
#
# class  49 :
# 从前，有一只8个触须的水母，长得像朵潘小花
# 你以为人生已经很艰辛了，但一条咸鱼的童年简直就是恐怖片
# 这片成精的“芭蕉叶”，竟是地球上最古老的动物？
# 长得仙风道骨，却是满手武器的凶残食肉动物！竟然有点……反差萌？
#
# class  50 :
# 一到冬天你妈就觉得你冷？该想想办法了
# 想上天下海无所畏惧？先学会保暖吧
# 睡不好，多半是因为你算错了“数学题”？
# 防风防水防极寒，这件羽绒服穿到世界末日大概也够了
#
# class  51 :
# 台风天里摇晃的摩天大楼安全吗？不会是豆腐渣工程吧
# 爱迪生发明留声机的时候又没有唱片，他把声音录哪儿了？
# 黑胶唱片，是怎么把声音留住的？
#
# class  52 :
# 剖宫产还是顺产，该由谁做选择？
# 艾滋家庭要孩子，只能用基因编辑吗？
# 贺建奎自称“借鉴了”权威伦理指南，但他一条也没遵守
# 面对一天拉10次的宝宝，宝妈们如何仙气满满？
#
# class  53 :
# 从兄弟变情侣，现在这对雄企鹅有爱情结晶啦！
# 以屎为溅！企鹅这种动物，喷屎的时候最可爱！
# 大冷天取暖，企鹅流行组团扭秧歌
# 太阳当空照，背上小挎包~激萌海洋动物挎包，陪大小朋友出去玩  好物推荐
# 这团萌物看似天真无邪，其实满脑子黄色废料
#
# class  54 :
# 从前有一只虫，因为头大，饱受嘲笑
# 切洋葱切到哭？人家法老可是承受了永恒的辣眼睛
# 只有直男才不会穿搭？其实不少女生也很辣眼睛  好课推荐
# 多吃猪肝真的能明目吗？
# 打错字的时候，手指比你自己更早知道
# 熬夜刷剧打游戏，你可不得眼睛疼么！
# 眼胀、眼干、见风流泪，随便花几十块买个眼药水有用吗？ 过日子
#
# class  55 :
# 快拿走啊！这梨丑到我了——等等，你说它很好吃？  好物推荐
# 来听东北老妹儿细数南北方饮食的刻板印象
# 盘点东北那些长得磕碜却好吃的美食
#
# class  56 :
# “奥陌陌”都飞远了，你才跟我说它没准儿是外星飞船？  迈向太空
# 中国自己的“SpaceX”，啥时候才能上天？ 迈向太空
# 又搞事儿了！马斯克到底是想开公司还是当网红？
# 小小“洞察号”：从今天起，替人类聆听火星的亿万年回忆录  热点
# 时隔51年，第25个去往月球的人类，是不在乎世人看法的日本土豪
# 键盘上奇怪的字母排列方式，140年来竟然难以更改丨智能生活
# 首个即将开启登月之旅的人类，知道自己坐的是什么飞船吗？  迈向太空
# 马斯克挖的洛杉矶地底隧道，马上就要开通接客了！
#
# class  57 :
# 我看看你这个手相啊......哎呀！太干了啥也看不出来！
# 有前中后调的香氛护手霜，连贝嫂都喜欢  好物推荐
# 香奈儿5号和迪奥小姐的香水原材料，竟长得这么其貌不扬
#
# class  58 :
# 三伏贴治不好哮喘、鼻炎等慢性病，还可能贴出化学灼伤
# 如果能重来，我不要做一换季就过敏的小孩
# 欧美医院没有青霉素皮试，他们不怕过敏吗？
# 花一千块把自己扎成筛子，为了向世界证明我真的大蒜过敏
# 蜂王浆的保健功效可信吗？小孩能吃吗？
# 被过敏禁锢的人生，我连呼吸都痛  AI夜话
#
# class  59 :
# 世界上最不受欢迎的书，很可能是说明书
# 拼个量子积木，竟然还有流派之分！ 荐物
# 给薛定谔加猫？量子力学思想实验“诡异程度又上新台阶”
# 超萌柯基，教你如何关爱设计师  好物推荐
#
# class  60 :
# 8位Nature特约书评人推荐的夏日读物，有你喜欢的吗？
# 一个村子命名了四种化学元素，这是什么神仙地方？
# 关于黎曼猜想的15个八卦（男女老少都能看懂！）
# 定义“千克”的仪器不准了！昨天，它惨遭全世界抛弃
# 黎曼猜想到底有没有被证实？同行似乎并不买账
# 黎曼猜想即将解开？这个“纯数学领域最重要的问题之一”，一篇文章讲清楚
#
# class  61 :
# 世上无难事，只怕有钥匙——甚至洗衣服
# 丝绒暖蓝睡衣，让你的冬天有温度  好物推荐
# 噼里啪啦一路火花，静电这么厉害会电死人吗？
# 秋天来了，静电还会远吗？
#
# class  62 :
# 1年只卖10天的黄桃，晚收一个月只为更好吃！ 好物推荐
# 奇异莓拼团最后一波，错过就等明年啦！ 好物推荐
# 如何吃到一枚甜到不要脸的猕猴桃？
# 爆卖50000颗的黄桃，拼团最后一天，再不吃就没啦！
# 超好喝小甜酒限时拼团，单瓶立省50 ！ 好物推荐
# 长得像枣，浑身没毛，你却告诉我它是猕猴桃？！ 好物推荐
# 高山丑苹果：长得丑怎么啦？能甜到你心里就够了！ 好物推荐
#
# class  63 :
# 99%的人擅长买书，只有1%的人用对了读书法丨好课推荐
# 中国一年出版255106种图书，你读了几本？
# 大家都用Kindle压泡面，背后是电子书的溃败  深度
#
# class  64 :
# 打水漂的必胜秘诀已被研究出来了，学会后你可能会赢到没朋友
# 较真研究打水漂的技术，从此不再“打水漂”！
#
# class  65 :
# 你喝奶茶睡不捉，好巧，我也是  AI夜话
# 咖啡果肉是甜的？猫屎咖啡好不好？咖啡的传说和真相都在这里
# 开水究竟有什么魔力，让中国人喝了上千年
# 当你喝水的时候你在喝些什么？丨内有福利
# 拉粑粑是坐着好还是蹲着好？我们录了个视频记录了测验过程！
# 莫名其妙失眠了？可能是奶茶惹的祸！
# 这也不让吃，那也不让喝，干啥都危险……怀孕就不能享受生活啦？ 好物推荐
# 适度饮酒有益健康？不存在的！
# 那杯奶茶下肚，我经历了迄今为止最接近死亡的三天
#
# class  66 :
# AI：给人看病太难了，带不动啊！ 智能生活
# “酸碱体质”创始人被罚一亿美元！装医生的神棍们，下场再惨都活该丨热点
# 在精神科，我们找到了脑控的真相  深度
# 家人患有遗传病，我难道没有权利知道？
# 对话乔尔·杜德利：中国有望成为数字医疗的领军者  智能生活
# 我在美国看痔疮
# 我的菊花里爬出一条绦虫！医生：我从业30年都没见过你这病例
# 我被误诊了！看病的时候别胡说，小心医生信了你的邪
#
# class  67 :
# 小蓝金刚鹦鹉野外灭绝，从此再无里约大冒险
# 跨大陆PK，到底谁才是最可爱的鸟儿？ 好物推荐
#
# class  68 :
# 中秋赏月遇到“隐形怪”，除了用月饼砸一下还能怎么办？
# 手机又没电了！说好的超长待机啥时候实现
# 能力飞跃瘦身可期，锂电池表示对电动交通未来保持乐观！
# 这是怎样的腿，让两位科学家相爱相杀，无法自拔？
#
# class  69 :
# “娘化”的美少年，碍着谁了？ 热点
# 你在网上勾搭的对象只比你好25%，大家心里还是很有数的嘛
# 对方适不适合你？这是最简单的真爱鉴定办法了
# 恋爱科学：一见钟情，只需要0.3秒
# 新垣结衣在职场总是这么温柔可人，她为什么不试试女王气场？
# 聊天时，我多回了两句，那男生咋就自作多情了？
#
# class  70 :
# 我们找到6位果壳编辑，分享了他们关于牙齿的惨痛故事
# 热销款美白牙贴，美白不牙酸，现在直降100元特惠啦  好物推荐
# 自从用了牙线，我都敢在喜欢的人面前露出龈笑了丨好物推荐
#
# class  71 :
# 万圣节的“幸运”饼干，你敢吃吗？ 好物推荐
# 为什么一粒灰尘可以长成六边形的雪花？
# 牛轧糖和饼干的结合体，你能想到是啥吗？ 好物推荐
# 福建人是吃这些好东西长大的，怪不得广东人一直惦记
#
# class  72 :
# 怎么回事儿，我一回家就想扯掉自己的胸罩！
# 最·正确测胸围方法来了：D杯的妹子别再被卖家骗着买B杯啦！
# 腰围测的竟然不是肚子！天天说三围，你真的会测吗？ 过日子
# 选对尺码，内衣还是不合适？因为还有这些问题你没考虑！
#
# class  73 :
# 一张嘴就咔咔响、疼痛难忍，王源和你得了同样的病
# 冬天穿短裙，到底会不会冻出关节炎？
#
# class  74 :
# 一个人旅行也想get美美的自拍！有这个神奇，自拍从此不求人丨好物推荐
# 减少妊娠纹、保湿抗氧化，橄榄油护肤真有这么神吗？
# 备胎当到老？想的美，备胎也要经常换的好吗
# 接受基因疗法后，这个失去皮肤的“蝴蝶男孩”活了下来
# 经常自拍老四岁？自拍会伤害皮肤吗？
# 花大笔钱来抗老，结果你的皱纹是睡出来的！
#
# class  75 :
# 一半中国人感染了幽门螺杆菌，只是你不知道！
# 丁丁是放左边还是右边？女生们好奇丁丁的点都有哪些？
# 对嘴巴好点儿，不然你的心胃肠脸甚至丁丁，都要不高兴
# 我这嘴里不是滋味，到底是一种什么滋味？
# 除了止血牙膏，你在牙口上还交了多少智商税？
#
# class  76 :
# “没手没脚”的植物们被害虫欺负了，该如何还击？
# 你知道吗，扫帚可是从地里长出来的
# 植物被骂30天会枯死？来，干了这碗假鸡汤
# 注意了！这10种植物不宜在卧室摆放  过日子
# 茶渣、烟灰、过期牛奶你都往花盆里倒，还问为什么把花养死了？
# 那场贸易战，打败我们的仅仅是鸦片吗？ 好课推荐
#
# class  77 :
# 你可能尝不出葡萄酒的好坏，但你能尝出果蝇味和瓢虫味儿
# 自己在家酿葡萄酒？小心喝完眼失明！ 过日子
#
# class  78 :
# 癌症带走了李咏，早期筛查是否能带走癌症？  热点
#
# class  79 :
# 2018诺贝尔医学奖：在癌症面前，松开免疫系统的“刹车”  直击诺奖
# 一个年轻人的死亡和儿童癌症研究
# 一天内让两位名人去世，这种病是“癌症之王”
# 今年诺奖研究是个啥？曾经化疗都没用的晚期癌症，有了特效药
# 医生给我拍片子时，到底在拍啥？ 过日子
# 我爸说红肉致癌，我妈说红肉有益健康，我还能不能好好吃肉？
# 漫画解读诺贝尔医学奖：如何关门放狗，咬死癌细胞！
# 癌症发病率越来越高，吃“防癌食品”有用吗？
# 癌症能从一个人传到另一个人吗？这些案例可能颠覆你的认知  深度
# 鼻癌鼻咽癌分不清，这些病能预防吗？
#
# class  80 :
# 上万只海螺才提取出1克，这种染料，是权贵的颜色
# 什么！海螺里的“大海声”，其实是脑袋里的水声？
# 原来，那么多富丽堂皇的音乐厅都是花架子
# 声音是带颜色的，比如风声雨声就是粉的！
# 幻觉来了，你猜是眼睛骗人还是耳朵骗人？
# 救命！我的耳朵里怎么老有嗡嗡声丨过日子
# 有人就爱空气突然安静，怎么了？
# 海螺珠，50000个海螺才出1颗的粉红奇珍
# 要吼多大声，才能震碎玻璃杯？
#
# class  81 :
# THIS IS AI：一场新奇的辩论和一个可期的未来
# 什么！我吵架居然还吵不过一个“冰箱”
# 对话PlayStation中国区负责人：我们做得那么烂，玩家还支持，这很不容易
# 这个叫熊浩的复旦才子，《奇葩说》男神，一开口便是人生赢家  好课推荐
# 这位施主，“AI 宗教”了解一下
#
# class  82 :
# 2018诺贝尔物理学奖：从科幻照进现实的激光  直击诺奖
# 漫画解读诺贝尔物理学奖：镊子和手术刀，居然都是激光做的！ 直击诺奖
# 激光点痣可能致癌！好在有种祛痣方法安全又彻底
# 百年诺贝尔物理学奖，女性得主：3人
# 这世界有那么多不确定，可唯我爱你这件事，我十分确定
#
# class  83 :
# 一个T细胞，没通过考试，然后它死咗
# 从大海中摘取希望之光的人，走了
# 你以为你有多少血？九瓶矿泉水的量而已！
# 你体内的“女仆大姐姐”究竟有多厉害？
# 你体内，真的有扎着双马尾的细胞
# 喂，胖友，你都吃撑了怎么还往嘴里塞！
# 大脑也要扫垃圾：扫走衰老细胞，你可能会“永葆青春”
# 干细胞祛疤、端粒酶抗衰老，这些护肤品真的“得过诺奖”？
# 斗地主、变魔术，扑克牌洗几次才够？
# 本AI在B站受尽嘲讽，你们快来救（补）命（刀）啊！
# 没有脑子的生物也会学习吗？
# 电子烟或被香港全面禁止。它能减少烟草危害，还是暗藏威胁？
#
# class  84 :
# 21世纪是生物的世纪，因为，生物狗将转行到各行各业……
# 神奇动物在哪里，你都看懂了吗？
# 神奇动物课程：驺吾竟然是个猫脸猪牙的大蜥蜴精！
# 还有8个小时就上映了！《神奇动物》主创想先讲几句
#
# class  85 :
# 299元最多能打包带走18瓶酒  好物推荐
# 你只会拆零食，但我知道零食都是怎么包装的！
# 冲鸭！买一赠一，错过悔一年！ 好物推荐
# 嘴巴寂寞的时候，我都是吃它们拯救空虚  好物推荐
# 图片仅供参考？为什么我的肉丸粉里真的有大个儿肉丸！ 好物推荐
# 无核话梅是怎么去核的？居然不是老奶奶啃掉的！  好物推荐
# 除了铁板烧，鱿鱼这样做也好吃！  好物推荐
# 鮟鱇鱼有多丑，就有多好吃，连骨头都好吃！
#
# class  86 :
# 久站的、久坐的，小心腿上爬满“小蚯蚓”  过日子
# 坐以待病？我这老老实实呆着怎么就摊上血栓了
#
# class  87 :
# 不成对的袜子能干嘛？不如捐给科学家吧
# 闻臭鞋、舔臭脚，猫主子是什么毛病！
#
# class  88 :
# 《物种日历2019》正式发售  一本送猫，两本包邮，三本送锦鲤
# 《物种日历》外壳上的隐藏彩蛋，你的日历有这行小字吗？
# 准备好了吗？还有两个小时，《物种日历2019》正式发售丨好物推荐
# 别再问野生动物应该怎么救助啦，你想要的答案都在这里！
# 喜欢奇奇怪怪的冷知识？这份合辑，请查收  好物推荐
# 城市有记忆——物种日历『年度限定封面』故事揭秘  好物推荐
# 如何带孩子认识大自然？果壳出手了！
# 小朋友的大自然说明书，打开探索世界的正确姿势  好物推荐
# 来人啊，AI大发善心送《物种日历》了！
# 童年，你欠我一本《物种日历》  好物推荐
# 轻定制：《物种日历2019》，有格调的企业年终礼物  好物推荐
# 这是一份送给全球自然爱好者们的礼物！你的歪果盆友会喜欢的，可不止胖达！  好物推荐
# 靠吃货解决入侵物种？人类啊，太天真了
#
# class  89 :
# 啥，世界山峰高度有了新排名？珠峰被它比下去了！
# 给珠峰量身高，没想到原理这么简单！
#
# class  90 :
# 你惜“发”如命，他们拔头发上瘾
# 头发又双叒叕炸毛了，自来卷可怎么办才好？
# 头发头皮问题多，和这些瞎作的护发方法关系不小
# 无硅清爽、低泡又便宜，婴儿洗发水到底是不是成人的性价比之选？
# 问：发际线太靠后的话，需要给头皮涂防晒么？
#
# class  91 :
# 为什么还没培育出无籽石榴啊！好着急！丨好物推荐
# 入口爆浆的软籽石榴，终于等到了限时优惠！ 好物推荐
#
# class  92 :
# 你只想“一饱眼福”，但它们却可能因此死于非命
# 猪链球菌感染，和猪瘟有关吗？
# 非洲猪瘟持续蔓延，我们真的要抛弃红烧肉和猪排了吗？
#
# class  93 :
# 别再笑黑猩猩模仿你了，你模仿它的样子更傻气！
#
# class  94 :
# 吃土没有那么容易，每个蚓有它的脾气
# 落叶变成土壤，得等多久？
#
# class  95 :
# “17岁少女7000元黑市卖卵”刷屏，“疼哭”还不是最可怕的
# 美容院告诉你卵巢保养不能省？这就揭穿他们的谎言！
#
# class  96 :
# 光溜溜的皮肤大汗淋漓？这其实是人类的天赋技能！
# 求婚的、比赛的咋都来咨询我？我只是个搞抖音的啊！
# 紧张到指尖都冒汗？近距离来看看吧
#
# class  97 :
# 人工智能的画作都开始拍卖了，第一幅画你猜多少钱？
# 史上第一部AI创作的小说，读完之后我懵了
# 如果给你一个AI，你最想让TA做啥？
# 当AI学会性别歧视  深度
# 我用人工智能写rap和诗，但我想成为一个黄渤那样的演员
# 科大讯飞说“冒充AI”只是个误会，我们又找“真的同传”聊了聊  深度
# 秦曾昌：我们会和人工智能开战吗？丨有意思博物馆
#
# class  98 :
# 站着吃饭，会导致胃下垂吗？
# 肚子饿了，为什么会&quot;咕咕&quot;叫？
#
# class  99 :
# 世界上第一张在小行星上拍摄的照片！ 迈向太空
# 入侵太空还不够，NASA还把魔爪伸向了娱乐圈……
#
# class  100 :
# 三度呼吸困难，差点英年早逝，33岁程序员的急性会厌炎并不少见！
# 世界精英看硅谷，硅谷精英都想去火人节
# 为了坑害黑客，这群程序员不惜连自己也坑  智能生活
# 女程序员：闯入男性领地，她们是行业里不足8%的“外来者”  深度
# 每一个穿格子衬衫的程序员，都曾是天上的科技仙男
#
# class  101 :
# 三体系统制造的引力波什么样？高低声二重奏
# 为什么AI死活看不出谁长得好看？今天我们聊聊审美  有意思博物馆
# 如果说游戏教会了我什么，那就是......
# 掉到黑洞的时候，人是怎么死的？这取决于你的瑜伽水平
# 高中生都能算对的万有引力题，牛顿却没办法做出来？
#
# class  102 :
# 为啥有的南瓜吃到连皮都不剩，有的只能用来做南瓜灯？丨好物推荐
# 你一定也听说过这种瓜，千万不要吃！
# 好吃到连舌头都要咬掉的贝贝南瓜限时拼团，别再错过了！ 好物推荐
#
# class  103 :
# 乌克兰军方用123456当密码？你以为你的就很难吗！
# 这幅图里背后的故事，你能看懂吗？
#
# class  104 :
# “清宿便，排肠毒”？别逗了，哪来那么多“宿便”给你清啊！
# “给你点颜色看看”的“颜色”是什么色？
# 为什么淤青有的紫、有的青，时间长了还会变黄？
# 为什么秋天的叶子，有的变黄、有的变红？
# 五彩斑斓的鸟蛋，你们都搁哪儿染的色？
# 动手玩：彩虹糖遇水，就溶成了五彩色盘
# 大便带血、尿液起沫、黏痰拉丝，我得了什么病？ 过日子
# 实用教程：如何吃出彩虹色的便便？
# 循环食用金针菇，保你“尿血”火龙果——这些食物什么毛病！
# 明明是黄色却叫红花，命名也太不走心了吧！
#
# class  105 :
# 冰箱不是保险柜！要保存好食物，得这样用冰箱
# 我打开冰箱，发现室友在里面放了一坨屎！  AI夜话
#
# class  106 :
# 别装x了，听古典音乐能有什么了不起的丨好课推荐
# 换个方式释放自己，会发声“溜溜球”来了，或成解压玩具新宠
# 整天说“动一次打一次”，你知道“动次打次”到底是啥吗？
# 没有BGM我都不会走路了：7个同音乐播放器有关的故事
# 音乐app：交互设计时代的欢乐颂
#
# class  107 :
# 如何熬过连上6天班的痛苦？吃点鲍鱼吧！ 好物推荐
# 懒得动的吃货，颜值倒是意外的高
# 那些成天吃松茸鲍鱼的都是些什么人啊？  好物推荐
#
# class  108 :
# 40万天价菜单上，那个死贵的大螺是什么螺，好吃吗？
# 好好一颗蘑菇，干嘛非要有毒？
# 死贵死贵的野山菌，会更有营养吗？
# 每天能吃几颗鸡蛋？关于蛋的疑问，一次性解答
#
# class  109 :
# “一个传染俩”的灰指甲，如何才能治愈？  过日子
# 做一次美甲，指甲薄一半，原来这真不是我的错觉  过日子
# 指甲上有小白点，原来是因为这个
# 被硬生生拔下指甲是什么体验？得了这种病你会懂的  过日子
#
# class  110 :
# AI学鸟：你们能御风而行，我也能！
# 今天中午，今年迄今为止，中国民航最接近灾难的一刻发生了
# 只要跑得够快悲伤就追不上你，但GPS可以啊！
#
# class  111 :
# 一颗陨石砸在哪儿，才能毁灭全人类？
# 地球上真实的“冰与火之歌”被证实，比美剧壮烈一万倍！
# 被陨石砸中的概率有多大？反正比你中彩票还难
# 野火烧光森林，它们竟还趁火打劫？
#
# class  112 :
# 不要998！不要98！这么美的宝石几十块钱带回家！
# 鸽子蛋不如鸽血红：比钻石还贵的红宝石是什么来头？
#
# class  113 :
# 2018诺贝尔经济学奖：市场有两件事做不好，他们指了一条出路  直击诺奖
# “兄弟们，起劲儿吃！”全球变暖，让这种不挑食的虫子更猖狂
# 漫画解读诺贝尔经济学奖：经济学中的作用力和反作用力  直击诺奖
#
# class  114 :
# 小奶狗用生命卖萌，这不是逼我弃猫养狗吗！
# 狗狗总想跟我碰鼻子，是爱上我了吗？
#
# class  115 :
# 卖断货的网红冰淇淋又悄咪咪地回来啦！ 好物推荐
# 阿月浑子：原来开心果的大名这么洋气
#
# class  116 :
# AI识物，到底是门怎样的生意？
# 我在阴雨天不开心，你也是吗？
# 能看穿假笑的AI，离我们还有多远？
#
# class  117 :
# 夜里总是磨牙咋回事儿，用治不？
# 清清白白一颗智齿，怎么变成了碍事的牙？
# 猫狗粮过硬，害主子崩断牙？不，那是TA们在换牙
#
# class  118 :
# 总有一些鱼，妖艳得让人下不去嘴
# 超凶！萌萌哒河鲀一口下去，螃蟹一半没了！
#
# class  119 :
# 大冬天的还有鲜桃吃？冬雪蜜桃，今年最后一次吃鲜桃的机会！好物推荐
# 想吃新鲜的桃子何必等明年？冬雪蜜桃，仅售2周！ 好物推荐
#
# class  120 :
# 放开买卖野生动物制品禁令，能够打压走私盗猎吗？
# 无论黑犀白犀，只要活下去都是好犀
# 解禁虎骨犀角入药，对老虎犀牛来说意味着什么？
#
# class  121 :
# 99%的人嫌自己读书慢，只因为他们不知道这些  好课推荐
# 一边注水一边放水的泳池管理员，你良心不会痛吗？ 好课推荐
# 你们要的回血课：在赚钱这件事上做个专业选手  好课推荐
# 你愿意当个废物吗？其实这事儿还挺难的  好课推荐
# 你绝对想不到，那个什么都能搜到的人，过的到底有多爽
# 减肥≠吃草！你被这些减肥谣言坑过吗？ 好课推荐
# 太坏了，居然用刘慈欣的小说引诱我学物理？
# 孙悟空为什么总喜欢给人（妖）当外公？ 好课推荐
# 现代人读书，就靠摸  好课推荐
# 秋日逛街背什么？Geek风帆布包拯救你  好物推荐
# 趁年轻，多跟心理学家交朋友  好课推荐
#
# class  122 :
# 为什么月经叫“大姨妈”，不叫“小姨夫”“大表姐”“二婶子”？
# 布洛芬不是鸦片，痛经难受吃一颗吧！
# 这次大姨妈，我专门计算了一下自己总共流了多少血  过日子
#
# class  123 :
# 一群蚂蚁达到多少只会出现分工？
# 洞穴那么窄，蚂蚁如何防止“堵车”？
#
# class  124 :
# 伯劳：嗨，美女撸串吗？
# 古埃及的太阳神，或许是个屎壳郎
# 暗黑爱情故事：为了求偶，含笑饮砒霜
#
# class  125 :
# 在谷歌与比特币背后，互联网消耗的能源超过你想象
#
# class  126 :
# 揭秘三百年前的高危职业：男士爱美起来会把人逼疯
#
# class  127 :
# 没想到，肾结石放到显微镜下居然这么好看！
#
# class  128 :
# 2018诺贝尔化学奖：让演化的力量为人所用  直击诺奖
# 会进化的药物：类风湿关节炎与牛皮癣神药的诞生  直击诺奖
# 漫画解读诺贝尔化学奖：达尔文进化论的活学活用！ 直击诺奖
# 这些夺命又“劫财”的细菌克星，能代替抗生素吗？
#
# class  129 :
# 为什么有些人分手后还能做朋友？
# 昨天还开开心心一起玩游戏，怎么今天就闹分手了？
#
# class  130 :
# 7天背完整本GRE，我的心路历程都写在这里了  好课推荐
# 年轻人，你也健忘吗？焦虑的不止你一个
# 谁说记忆了无痕，它明明在脑子里留了印痕
#
# class  131 :
# 为什么西梅总被做成干？新鲜的肉体不好吃吗？
# 这个西梅吃起来真的好焦虑，生怕吃得慢就下架了  好物推荐
#
# class  132 :
# 你们这些北方人别再说火腿是火腿肠了！好物推荐
# 家里有矿的人吃什么？看看那些食物界的奢侈品
# 有了这些神器，看谁还敢在你身边乱抖腿
# 盘点《风味人间》里那些没说完的中国美腿
#
# class  133 :
# 夭寿啦！喵星人又在打奶架，它们是闹着玩还是来真的？
# 得了白癜风又怎样，我照样在维密舞台走秀
# 我家主子会隐身？每天在家上演神奇动物在哪里......
# 猫猫以7倍于人的速度离开世界，如何让ta拥有幸福晚年
# 盒子放久了就会长出猫，亲测有效  好物推荐
# 笑死我了，这些猫怎么长得这么沙雕
#
# class  134 :
# 只有初中词汇量，却和老外畅聊无阻，我是怎么办到的？ 好课推荐
# 国庆将至，我猜你非常需要这个海外旅行英语&quot;急救包&quot;丨好课推荐
# 学英语效率低？你该来全网最酷英语角！丨好课推荐
#
# class  135 :
# 00后黑话词典，来看你认识几个
# 我们在南极跨出的每一步，可能是人类的第一步，自己的最后一步
# 本想在南极户外吃碗面.....诶？
# 速冻饺子的营养和安全，都比亲手包的差吗？
#
# class  136 :
# 今年没有诺贝尔文学奖了？来，咱们今天吃个文学味儿的瓜
#
# class  137 :
# “茶”界也分甜咸党？此茶非彼茶！
# 什么神奇的“汤”，把碗倒扣都洒不出来？
#
# class  138 :
# 食品包装里的小袋子都装了什么？不是只有干燥剂那么简单
#
# class  139 :
# 伦敦这里变弯，是因为“万人坑”，还是天价拆迁费？
# 在地铁坐满4小时，你的身体会发生什么变化？
#
# class  140 :
# 5天不喝水，还狂跑80千米，角马你们不会热到炸吗？
# 还堵在返程路上的你，知道人家是怎么回去的吗？
#
# class  141 :
# 不漏水的茶包！原理其实这么简单？
# 喝普洱茶真的可以“刮油”吗？
# 天气转凉瑟瑟发抖，除了喝热水穿秋裤，还有什么办法能驱走寒意呢？  好物推荐
# 抹茶的N种美妙的可能性里，不能错过的是它  好物推荐
#
# class  142 :
# 只能戴套或结扎？男性避孕新招数，了解一下
# 相爱就要被爆头，这样的恋爱我承受不来啊啊啊啊啊啊
# 精子在跑马拉松，最快最强者获胜？不，它们只是在抽奖
# 自割大腿、前攻后受：只要能交配，让我干嘛都行丨七夕
# 臭虫的爱情：一发入魂！
#
# class  143 :
# 中国自主研发“鸽子”无人机，能骗真鸟、避雷达
# 小熊奋力爬悬崖很励志？明明是被人类吓到了！
#
# class  144 :
# 会提出虚假性侵指控的，都是些什么人？
# 名人科学家被指控性骚扰，学校却仍为他保留教职
#
# class  145 :
# 又到了“1023摩尔日”，今年的主题是——摩利波特
# 庆祝摩尔日，手帐达人教你做Geek风书签、手帐！ 好物推荐
#
# class  146 :
# 世界艾滋病日：阻断HIV感染的黄金24小时
# 令人们谈之色变的艾滋病，是从哪来的？
# 国内首个原创长效抗艾新药正式上市，到底有何奥秘？
# 那年我的腰上长出了“北斗七星”，让我哭了整个春天
# 飞机四处着陆，坐飞机的我会染上可怕传染病吗？
#
# class  147 :
# 考古学家在古城找到了有图案的马赛克，却没想到画面如此三俗……
#
# class  148 :
# AI不听话，谷歌要给Ta们安上“紧箍咒”了！
# 为了保护用户个人隐私，欧盟竟把企业逼到“自杀”了
# 程序员们的社交狂欢长什么样？看看谷歌开发者大会
#
# class  149 :
# 经常嚼口香糖，会得胃病吗？
#
# class  150 :
# 不是所有的疙瘩都叫“痘痘”！没对症下药，难怪你的脸总好不了
# 口碑产品DR. WU杏仁酸，限时拼团立减50元，你的入门酸马上get！ 好物推荐
# 我的痘痘从初中起就没好过，有什么办法治治吗？丨AI夜话
# 晚上吃姜赛砒霜、隔夜水不能喝？“生活小窍门”的真相在这里  AI夜话
# 用“祛痘神药”的这段日子，没想到这么难熬
# 节后上班怎么都爆痘了？有一种急痘攻心叫压力很大
#
# class  151 :
# 为什么你吃不到真阳澄湖大闸蟹？它们没被捞起就已经被卖掉啦！
# 怎样买买买才能又走心还不伤肾？
# 距离中秋只剩4天了，你是不是忘了些什么？ 好物推荐
# 阳澄湖终于开湖了，如何才能避免买到“洗澡蟹”？ 好物推荐
#
# class  152 :
# 自从知道红领犯罪，我开始感激每一位不杀我的同事
# 谢同事不杀之恩……工作场所排第三的死因，竟然是谋杀！
#
# class  153 :
# 6.97吨碳九泄露，危害会有多大？丨热点
# 99%的人都不知道，易拉罐里还藏着一个透明的包装
# “哎呀，明明咱俩干的活一样，怎么我拿的钱比你多这么多啊？”
# “喂，专业名词，你是魔鬼吗？”
# “国民零食”九制话梅，是哪九制？
# “抽动秽语综合征”都被拿来骂人了，能别这么叫我么？
# “表情移植神器”上线，我家爱豆的面瘫演技是不是有救了！
# 《风味人间》里没说完的馕，这次给你说得明明白白
# 一只鹿说：别吓唬我，信不信我“汪”地一声叫出来？！
# 一滴水就能做的显微镜，快点来试试
# 不切不尝不咬开，商家是怎么测水果甜度的？
# 不是我不想穿越到过去，是我舍不得空调和暖气
# 世界上最坚硬的食物，我打赌你一定吃过！
# 世界上最小的青蛙，能在你指甲盖上跳舞！
# 为了避免物种大灭绝，一半地球都该划成保护区，问题是划哪半？
# 为什么中国99.8%的鸟都是由外国人发现和命名的？
# 为什么总用五角星表示星星？人家明明是球体啊！
# 为什么有人放假第一天就写完了作业，而你开学前夜还在赶
# 为什么汤圆会在沸水中翻滚，煮饺子却不会？
# 为什么硬核游戏《太吾绘卷》独宠斗蛐蛐？因为真的很好玩啊
# 为什么科学家、医生、教授要穿白大褂？
# 为什么蟑螂喜欢爬进人耳朵里安家？ 过日子
# 为啥火车票和身份证一样大？又被检票员一块儿剪了！
# 为啥语文永远考不了高分老师们这么说……  好课推荐
# 亚马逊无人超市开业了，我在里面“偷”了样东西
# 人类最早具象画被发现啦，你猜猜画的是啥动物
# 人类这么热衷探索宇宙，为什么只有两艘探测器去过水星？  迈向太空
# 人肉的营养价值有多高？人的哪个内脏最有饱腹感？
# 什么样的空气质量，让你的鼻子分分钟要罢工？ 有奖问卷调查
# 什么汤能喝出风起云涌的味道？一定是味噌汤！
# 今天是世界预防自杀日：第一步，让自杀能被公开讨论
# 今日的脑洞题：重建整个人类文明，需要多少人？
# 以“科普虎鲸”之名，行圈养之实，海昌海洋公园请停手！
# 以形补形？老外也是被坑过来的
# 你就是漫威世界里最棒的超级英雄，你将获得的休息远比所知道的一切都甜蜜
# 你已经是个成熟的LaTex了，该学会自己写论文了
# 你开核桃用锤子，别人开核桃用玩具士兵
# 你是多久没洗衣服啦？领子上长鹦鹉螺了都！丨好物推荐
# 你画过这种一点卵用都没有的饼图吗？收手吧！
# 入门艺术插花，你需要先了解一下这株花
# 关键时刻起不来，是身体不行还是心理因素？贴几张邮票测一测
# 冒死回国，造福中国航空，他就是中国材料科学之父师昌绪
# 冬虫夏草正在消失，但他们除了继续挖没有别的选择
# 几十亿的诺奖基金，最初都是卖炸药赚来的吗？
# 出门就堵上网就卡！怕不是见“鬼”了？
# 刚敲了一天键盘的社畜们，或许你们得过腱鞘炎？这种自测方法靠谱吗？  过日子
# 别看我做事拖延，但做决定很冲动啊！
# 别等双十一了，今天辣卤肥肠的折扣已经打到底了！ 好物推荐
# 十大奇葩的假币制造者：连错别字都印上去
# 卫龙下架，辣条添加“违禁物”？这其实是个历史遗留问题
# 双眼皮贴怎么用？这种最便宜的“整容级”小工具，赶紧掌握起来！
# 反抗主流的小众青年们，为什么看起来长得都一样？
# 古人想吃点儿垃圾食品，用什么油炸？
# 吃个橘子就跟喝鲜榨果汁一样？甜蜜多汁到爆的蜜橘了解一下！ 好物推荐
# 听印第安人讲自己的历史 ：一个斯坦福学者的印第安文化回归之旅
# 啄木鸟吃个虫这么辛苦，收支能平衡吗？
# 喷子简史：当年“匡扶正义”的网友，如何成为今天尽情狂欢的嗨粉
# 喷完摔不碎！“变强喷雾”是怎么做到的？
# 噫！这个星星，长得有点不可描述……
# 国库里亮瞎人的黄金，是怎么做出来的？
# 在普通打印纸上加记忆材料，做出来的立体书太魔性了
# 地球史上最大的动物，嗓子眼只有排球大
# 夏天掌中宝，冬天一边撂，让我们采访一下当事人空调
# 大胖子+小短腿+暴力狂，这竟然是天鹅？
# 天下武功唯快不破：A4纸发起火来，连诺基亚都得怕！
# 太好骗了……啥也没变的魔术，照样有人觉得“好神奇哦~”
# 太美的鲫鱼舍不得炖，于是有了金鱼
# 女生的裤兜竟然比男生的小这~~么多，量完我自己都惊了
# 如何成为一条锦鲤？
# 学习计划超详细的那个同学，怎么反而越学越差了？
# 学好线性代数，成为亿万富翁不是梦
# 家长有多大的怒火，霉变的蔬果就有多危险！
# 对话《碟中谍6》：开拍前，我们没有剧本
# 小时候就好奇听诊器该怎么玩，这次终于知道了！
# 左边还是右边，我今天该穿什么？问问电商平台  深度
# 干过的坏事转眼就忘？人人都可能是朵“白莲花”
# 恰好没有赶上公交？恭喜，你是被概率选中的人！
# 悔得直抽自己嘴巴？疼痛，真的能缓解你的内疚吗？
# 感恩节：殖民者用瘟疫书写的传说
# 慕容云海送错项链了！土星不仅有环，还会下雨呢
# 懒人的幻想之一，周末不用洗衣服。恭喜你，可以实现！
# 成分堪比期货，一年暴涨十倍，这是咋回事？
# 我今天吃了一盆盆景，并且，还没吃够……  好物推荐
# 我国新装房屋甲醛普遍超标，如何去除家中甲醛？自测甲醛靠谱吗？
# 手背上凸起的肿块被我捏瘪了，医生我还有救吗？  过日子
# 打嗝打出屁，燃烧牙结石？龙原来是这样喷火的！
# 拿筷子夹还总碎的腐乳，是怎么在玻璃罐里码得平平整整？
# 指引哥伦布发现新大陆的原来是他！埋没了1300年的全能学霸
# 搁以前，什么样的人能穿貂儿？
# 放走大颗粒，留下小颗粒，这是什么过滤操作？
# 教你一招，系鞋带如何能不再松开？
# 教辅成精，你怕了吗？
# 斑马是黑条的白马，还是白条的黑马？
# 新款炫彩iPhone，用肥皂水做一个！
# 无骨鸭掌也是老奶奶啃出来的吗？ 好物推荐
# 日常生活中这些bug，真的无药可救么？ 有奖征集
# 明年春天的樱花，居然现在就开了！来年还能看得到吗？
# 春蚕到死，就吐了一根丝
# 是时候把你家的保鲜膜换成“马德堡半球”了  好物推荐
# 最绝望的单身：世界上再无同类
# 月下的梅酒啥味儿？刚好有个优惠了解一下！好物推荐
# 有了这个，你的PS可以不用学了
# 有种触屏一代不知道的爽，叫做“按钮”
# 横纹衣服更显胖？你可能一直都弄错了
# 水变“牛奶”，这可是厨师的基本功！
# 水银温度计、耳温枪、电子体温计，量体温到底哪个最准？ 过日子
# 求求你别帮我！我不想欠人情债
# 没有锦鲤的运气，怎样放心买买买？
# 泡尸水都想喝？那这些“史诗级”大餐一定馋哭你！
# 洗澡时镜子老起雾，真烦！抹点洗洁精就好了
# 淡水虹鳟终于成功打入海水三文鱼团体？会对我们有啥影响？
# 深夜和几百个吃货一起聊天是什么体验？
# 深夜思考一个恐怖问题：我身上的皮，能做成几把扇子？
# 混用iPad的充电器为iPhone充电，会出事吗？
# 添加“亚铁氰化钾”的食盐，有毒吗？不，它很安全  热点
# 游戏总打不过？别灰心，你还可以钓鱼
# 灰蒙蒙的古希腊性冷淡石雕，原本竟然这么妖艳？
# 烟熏制品致癌，怎么欧美还有这么多人吃？
# 烧完的火柴头被磁铁吸住了，这是为什么？
# 爹妈的时尚，家电的外套——蕾丝是如何编织的？
# 电影里总见坏人上电椅，电椅死刑究竟什么样？
# 白带变黄还有味儿，需要去看医生吗？丨过日子
# 白白净净的藕是工业浸泡的毒藕，这事儿是真是假？
# 白砂糖的新标准放宽了致癌物限量，吃糖再也不安全了？
# 皇后如何母仪天下？答案：喂你些屎
# 皮皮虾你飘了，居然对着摄像头指手画脚！
# 看完流水线取瑶柱...扇贝自己都想鼓鼓掌！
# 真·生化危机：十座最危险的毒物废城，探险需谨慎！
# 竹鼠：我没中暑，我没抑郁，我不漂亮，别红烧我！
# 红橙黄绿青蓝紫，颜色这么多，交通信号灯为啥是红绿黄？
# 纯果汁、冷榨果汁、鲜榨果汁……果汁的门道一篇给你讲清楚
# 绿植绿纸绿屏幕，绿色真的能保护视力吗？
# 罐头里的菠萝干干净净，那流水线上它怎么削皮去眼？
# 网传雪糕融化后再冷冻有毒？那到底能不能吃？
# 美少女无法抗拒的“柚”惑，每一口都是清新的味道  好物推荐
# 耐嚼易存、肌理分明的牛肉干，是怎么制作出来的？
# 能洗菜烘焙调酒还可以搞艺术，这个神器你家也有，它叫洗衣机
# 至少有100万非洲老铁认为赛亚人是黑人
# 英俊连环杀手谋害时尚大师，这段故事今天斩获3个艾美奖
# 著名减肥食品魔芋的前世今生，这次给你讲得明明白白
# 蓝莓表面的白霜是农药？冷冻蓝莓没有营养？关于蓝莓的3个真相
# 蛇界汉尼拔：为了争夺配偶，眼镜蛇竟会吃掉情敌！
# 要是伊犁鼠兔在我面前灭绝的话，我这辈子确实是无言了
# 计算机能隔“墙”视物了，这可能是各国军方最期待的黑科技
# 让你失望了，我只是自闭症，不是个天才
# 超可爱的墨西哥钝口螈，教你怎么让剁掉的手长回来
# 越痒越挠，越挠越痒，牛皮癣这病，我该怎么办？ 过日子
# 还记得你当年玩的笔仙游戏么，现在试一次你还怕不怕？
# 这个性感的办公室，可以让你们自愿加班到死！
# 这些伟大的科学成果竟然都是意外？快来围观大型科学锦鲤现场
# 这样挑到的厨刀，便宜又好用！一个刀具爱好者的私人攻略~
# 这种奇怪的动物，尾巴竟然是方形的！
# 这种萌翻全世界的小猫头鹰，能当宠物吗？
# 进了个下水道，发现比那些人山人海的景点好玩多了
# 连续153年坚守唯一的繁殖地，这种绝美极危水鸟今后路在何方？
# 那一刻，我的心脏选择了休息……
# 金沙江的堰塞湖有多危险？救援队伍在用生命抢救！
# 钻石燃烧什么样？烧给你看！
# 防雨？那不是事！我这衣服就差能防弹了
# 陪孩子写作业都能犯脑梗死？这种病还有更多雷区
# 隆重介绍下漫威史上最萌龙套，身长0.5毫米的透明小可爱
# 隔夜菜能吃吗？其中的亚硝酸盐真的“严重超标”了吗？
# 食物清洗指南：水果、大米、生肉、这样洗就对了  过日子
# 首个“年抛”避孕环，自己放入自己取
# 香山红叶不是枫叶！朋友圈里的红叶都是啥，来认识一下
# 魔性设计哪家强，霓虹人民喜洋洋
#
# class  154 :
# 为什么热水瓶内胆的底部，总多出一个激凸的小揪揪？
# 冬季送温暖！超可爱毛绒热水袋，给你一个暖萌的冬天  好物推荐
# 热水袋不就是土味儿养生吗？啥时候变这么好看了！ 好物推荐
#
# class  155 :
# 你听过熊猫叫吗？Ta的叫声还能当“身份证”
# 李彬彬：追逐萌神胖达  有意思博物馆
#
# class  156 :
# 人类“高光时刻”，无不从“消除混乱”开始，现在到AI了
# 你只是过一个马路，交通灯却操碎了心
#
# class  157 :
# 勘误及致歉声明
#
# class  158 :
# 我就是那个高度近视，戴最重的眼镜，每天都担心变瞎  AI夜话
# 我高度近视而已，咋献个血都被拒了？ 过日子
# 走出电影来到人间的裸眼悬浮3D，竟能如此酷炫！
#
# class  159 :
# 1.2秒，营造家的感觉
# 人类发展的动力，除了懒，还有对舒适的追求
# 无人车怎么处理车祸？在4000万个选择中寻找解决方案
# 有理有据！700年前就已经知道将有人工智能了
# 滴滴、Uber、Facebook：科技巨头如何变成新时代的“恶魔”？
#
# class  160 :
# 为了改善暴躁，他们想到了割人脑
# 前面那位大脑袋朋友，一看你朋友就特别多！
#
# class  161 :
# 为了挽救这种萌物，人们不得不杀死另一种
# 你只知道这些东西的名字，却对它们的大小一无所知
# 夜夜想起妈妈的话，这就是传说中的鲁冰花
# 天天打鱼还是狩猎采集，人类最初是怎么进入美洲的？
#
# class  162 :
# 我买了一个月饼打算送礼，结果没送出去......  好物推荐
# 月饼里只有咸蛋黄，那蛋白都被糕点师啃了吗？
# 比起花样百出的月饼，我独爱月亮里温柔深沉的兔子
#
# class  163 :
# 泰国登革热疫情爆发，国内这些地方也有感染风险！预防方法都在这
# 痒痒痒痒痒！为啥我的蚊子包，比别人的更痒？  过日子
#
# class  164 :
# 虽然我命途多舛运气差，但我拿了诺贝尔奖
#
# class  165 :
# 学不好数学，你可能连朋友也找不到！
# 当所有法官都一致认为有罪时，为什么犯人反而被无罪释放了？
# 我们眼中平平无奇的生活现象，在数学家眼中竟然是这样的
# 有人证明出π=4，这是什么鬼？
# 还没瘦下来夏天就要过去了，时间咋过得这么快？
# 这些魔性动图，我能再看俩小时！
# 透过科学滤镜，看到别样之美
#
# class  166 :
# 动物去哪儿：野生动物迁徙路线大揭秘
# 屁股的诱惑无法抵挡？沉迷于此的可不只是人类！
#
# class  167 :
# OpenAI惨败：面对最菜TI战队，它输的毫无还手之力
# 中国LOL夺冠后，我们逛了Twitch：这个直播平台居然不捧美女主播！ 深度
# 在这些老板面前，王思聪打电竞联赛只能算小儿科
#
# class  168 :
# 他们推荐了这么多时间管理app，能让我成为一个高效的人吗？丨AI夜话
# 加速人生：为什么时间管理软件拯救不了你？
# 相比于温柔上司，霸道总裁更能管好公司吗？
#
# class  169 :
# 《如懿传》里周迅的蝴蝶结，《延禧攻略》里的云肩，哪个更不靠谱一点？
# 史上最全《延禧攻略》彩蛋，原来他俩还有感情线啊 ！
# 名画《呐喊》里扭曲的天空，居然是真实存在的？
#
# class  170 :
# 教AI玩马里奥：好奇心是最好的老师，这个道理AI也知道
#
# class  171 :
# 北方的冬天也太干燥了吧？我现在没它根本不行！ 好物推荐
# 花大价钱买保湿精华，不如添置一个高颜值加湿器？ 好物推荐
#
# class  172 :
# 这种珍贵奢侈的蘑菇，竟然是农林害虫种植出来的
# 金字塔有什么了不起？这些白蚁建了2亿个！
#
# class  173 :
# 吃进胃里的食物，你却指望它“清肺”？别逗了！
# 深夜报社：为什么有些食物只靠闻就能判定它格外好吃？
# 薯片炸鸡爆米花，你为啥喜欢嘎嘣脆的食物？
# 零嘴进军机器届：爆米花托起重物，就靠爆开那股劲儿
# 食物多样才健康，这个说法是错的吗？
#
# class  174 :
# 掌掴对象也算表白？！你怕不是要笑死我  漫画
# 等等，酵素不是拿来吃的吗？
#
# class  175 :
# 你猜，如何把一个地球掰成几个花？
# 减肥是不可能的，但减排还尚可一战
# 活着就是资源浪费？那是因为你活的姿势不对
#
# class  176 :
# 人们管我俩叫“最美双星”，但我们只是碰巧路过  迈向太空
# 地球：“喂，宇宙我在这里。”“对不起，您拨的号码是空号”  迈向太空
#
# class  177 :
# 保罗·艾伦去世了，我想复制他的人生
# 马航370又一次被找到了？防火防盗防小报啊朋友们
#
# class  178 :
# 变态难的物理游戏，你能玩到第几关？
#
# class  179 :
# 100万颗乐高零件打造1
# 没有光脚踩过乐高，你跟我谈什么人生！
#
# class  180 :
# 共用酒店马桶、毛巾和床单，会得上尖锐湿疣吗？
# 酒店杯子微生物检测为0，就能证明它的卫生合格了吗？ 热点
#
# class  181 :
# 一双鞋垫两三千，医院里的“天价鞋垫”是怎么回事？
# 看上去很美的“刑具”：今天，你的鞋子合脚吗？ 过日子
#
# class  182 :
# 为啥踢到脚趾会痛得要死？拜托，你只是个脚趾而已啊！！
# 在浴缸里泡澡，为什么手指脚趾会起皱呢？
# 鸡jio猪jio猫jiojio，其实都不是脚！动物都是用啥走路的？
#
# class  183 :
# 中国第一台大科学装置，今年30岁了
# 南极飞出了什么神秘粒子，让学术圈集体兴奋？
#
# class  184 :
# 妹子们的心里话：他丑又怎样？他是好人啊！
# 路见乞讨要不要给钱？再犹豫下就会反悔了！
#
# class  185 :
# 英国又现“麦田怪圈”，目前尚无外星人宣布对此事负责
# 这里有串“地球最古老的脚印”，请主人速来认领！
# 麦田怪圈的秘密，原来早就解开了？
#
# class  186 :
# 庞贝古城是哪天毁灭的？历史书可能又要改了
# 最厉害的“建筑师”，都是穿越星球找灵感的
# 炽热的爱情就像火山，遇上它们是否真的无处可逃？丨七夕
#
# class  187 :
# 世界动物日，我们把中国最美的猫科动物带给你  好物推荐
# 如果北京有90%的房子被棕熊扒过，我们会恐慌成什么样子？
# 这只大猫，是世界“最高冷”的佛系游侠
#
# class  188 :
# 人为什么要长下巴呢？这得问问鱼！
# 失去森林的红毛猩猩，过得真的快乐吗？
# 猩猩猴子都没有下巴，人类为什么会有？
# 让人改头换面的大整形，到底做的是啥？
#
# class  189 :
# 老是在梦里杀人？别怕，你可能只是很有创造力
#
# class  190 :
# 100年后，我终于用完了双十一囤的卫生纸丨漫画
# 剁手买的冬装，为什么等真正穿的时候就不喜欢了？
# 双十一把手都剁没了，别人却什么也没买？省钱的秘密在这里
# 辨别双十一“花招”：商家是如何用数字+文字劝你掏钱的？
#
# class  191 :
# 不睡不行、睡久不行，有技术含量的午觉这样来
# 大胸姑娘防下垂的利器！超舒适睡眠内衣  好物推荐
# 被鬼压床了怎么办？在线等，挺急的
#
# class  192 :
# 听说，果壳Tee已经沦为科学冷笑话大全了  好物推荐
# 应对多变的“薛定谔的天气”，你需要“薛定谔的猫”  好物推荐
# 我们一起学猎豹叫，一起……喵喵喵喵喵？
# 柯基哪里有意思？瞧，连屁股都在向你比心呢
#
# class  193 :
# 为什么一到冬天，北方城市总会聚集一大群乌鸦？
# 我们身边这种黑乎乎的小鸟，叫声居然这么好听！
#
# class  194 :
# 舌头那么怕疼，咬舌自尽真的行得通吗？
# 隐藏在金庸小说中的11个谜题
#
# class  195 :
# 教授年轻，经费不够？那我去“创业阶段”的实验室有什么好处
# 造假十多年，撤稿31篇，这位“心机”大牛因何骗过全世界？
# 韩春雨事件：迟到的校方声明，补上了学术自净的最后一环  热点
#
# class  196 :
# 当我在工位上浑身难受时，我知道是我的屁股在呼唤这款坐垫  好物推荐
# 拿什么拯救你？我那尊贵又无处安放的美（屁）臀（股）！ 好物推荐
# 这里有猫！好rua不挠人，还可以机洗的那种……  好物推荐
#
# class  197 :
# 低脂乳制品好吗？五位不同领域的专家这样回答
# 做香肠的未必是肠子，也可能是牛膀胱……20个香肠的冷知识
# 喝骨头汤大补？补的其实是脂肪而已
# 在最野的玩猪大赛里，人比猪还脏
# 开会打盹怎么办？别担心，迷迷糊糊时的你可能更有创造力
# 朕写了四万首诗都没人背，你们到底在背谁的
# 涮羊肉入门：上脑、黄瓜条、磨档，究竟哪儿最好吃？
# 秋天到了，我是不是可以开始贴秋膘了？
# 管住嘴，你说了可不算，这得听你家肥肉的！
# 精致的猪猪女孩男孩们，你们的体脂率可能比猪猪高！
# 这位年轻人，心血管像豆腐渣，他得了什么病？
# 金洋：分析世界杯、降低撞衫率，谁敢说数据无聊？丨有意思博物馆
#
# class  198 :
# 口水是最好的清洁剂？如何缓解职场压力？今年的搞笑诺奖很实用
# 得了肾结石怎么办？过山车疗法，了解一下
# 空腹吃柿子容易得结石？和螃蟹一起吃还会中毒？
#
# class  199 :
# 万圣夜干点刺激的！这是一份生造噩梦指南
# 小时候的动画片这么多bug，是欺负我们小学生没上逻辑课吗？ AI夜话
# 汤姆·哈迪：除了露足够多的脸，我在《毒液》里还做了这些
# 皮卡丘居然长毛了？喂，这才是人家本来的样子
# 连柯南本人都去看了这部电影，还被晃到模糊！这次死掉的是……

# %% [markdown]
# 算法将部分相似主题的文章成功分到了同一类别中，比如类别0有关航空航天，类别2有关科幻等等，同时，也有一些文章由于分布在稀疏区域等原因，被错误地与其他文章归为同一类，比如类别10。对于这种情况，我们可以专门提取这一类别的文章，再次进行聚类。

# %% [markdown]
# ## 总结与分析

# %% [markdown]
# 本次实验中，我们提取微信公众号的文章数据，采用K-means聚类算法。遇到的主要问题则是特征空间维度过高，使数据分布过于稀疏。为了解决“维度灾难”的问题，我们用不同的方法对特征进行降维。实验证明，降维后的特征仍能反映文章的主要信息，不会显著降低分类的合理性，同时通过减少数据量加快了算法的速度。
#
# 当我们将相同的算法作用于文章量为1000的较大样本，发现分类后的结果存在许多噪声与错误，这由多种原因造成：
#
# 1. 特征选取、PCA降维均有可能筛去能反映文章区别的关键词汇，从而减少有效信息，影响算法准确度。
# 2. K-means算法本身存在局限性。在聚类时需要规定类的数量多少，但事实上我们对应该分多少类并没有概念。
# 3. 样本集本身包含许多难以处理的样本。比如：文章长度过小，主题偏僻导致难以找到相似的文档。
# 4. 数据分布无规律、范围广。公众号的文章往往涉及生活中的方方面面，且不存在规律，不同类型的文章数量存在不平衡的问题。主题涵盖的范围甚广，使得样本原本的分布就比较稀疏。
# 5. 文本内容复杂多变，语言具有复杂性，一词多义、新词的出现降低了关键词的描述的准确性和全面性。
# 6. 以关键词作为特征的局限性。关键词虽然反映文档的一部分信息，但是忽略了语义层面的信息。首先，关键词之间可能存在同义、近义等关系，在模型中并未考虑词与词之间的关系，不同的词均统一代表不同维度。其次，文章的主题应通过对整篇文章的总体理解，但是关键词则只考虑单一、分裂的词，忽略了文章的整体结构与含义。
#
# 为了解决这些问题，我认为日后应当重视语义层面的信息，以下提出几点猜想：
#
# 1. 考虑关键词之间的语义关系、语义相似度，对同义词进行合并。
# 2. 引入知识库，从关键词入手分析归纳文章所涉及的主题或领域。
# 3. 对标题进行语义理解将有利于利用最少的数据获取大量信息，但是如何让算法理解语言文字传达的信息成为问题。

# %% [markdown]
# ## 参考文献

# %% [markdown]
# 1. https://github.com/fxsjy/jieba
# 2. https://cuiqingcai.com/1319.html
# 3. https://blog.csdn.net/shijiebei2009/article/details/39696571
# 4. http://brandonrose.org/clustering
# 5. http://brandonrose.org/top100
# 6. https://scikit-learn.org/stable/index.html
